# %%
import os
import pathlib

# Clone the tensorflow models repository if it doesn't already exist
if "models" in pathlib.Path.cwd().parts:
  while "models" in pathlib.Path.cwd().parts:
    os.chdir('..')
elif not pathlib.Path('models').exists():
  # !git clone --depth 1 https://github.com/tensorflow/models
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 3994, done.
# remote: Counting objects: 100% (3994/3994), done.
# remote: Compressing objects: 100% (3107/3107), done.
# remote: Total 3994 (delta 1150), reused 1967 (delta 830), pack-reused 0
# Receiving objects: 100% (3994/3994), 49.78 MiB | 15.55 MiB/s, done.
# Resolving deltas: 100% (1150/1150), done.

# %%
# !pip install tensorflow==2.12.0
# Out:
# Collecting tensorflow==2.12.0
#   Downloading tensorflow-2.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (585.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 585.9/585.9 MB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (1.59.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (3.9.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (0.4.16)
# Collecting keras<2.13,>=2.12.0 (from tensorflow==2.12.0)
#   Downloading keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 66.3 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (16.0.6)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (1.16.0)
# Collecting tensorboard<2.13,>=2.12 (from tensorflow==2.12.0)
#   Downloading tensorboard-2.12.3-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 70.3 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.13,>=2.12.0 (from tensorflow==2.12.0)
#   Downloading tensorflow_estimator-2.12.0-py2.py3-none-any.whl (440 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.7/440.7 kB 43.8 MB/s eta 0:00:00
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (0.34.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.12.0) (0.41.2)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow==2.12.0) (0.2.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow==2.12.0) (1.11.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.0.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.2.2)
# Installing collected packages: tensorflow-estimator, keras, tensorboard, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.14.0
#     Uninstalling tensorflow-estimator-2.14.0:
#       Successfully uninstalled tensorflow-estimator-2.14.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.14.0
#     Uninstalling keras-2.14.0:
#       Successfully uninstalled keras-2.14.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.14.1
#     Uninstalling tensorboard-2.14.1:
#       Successfully uninstalled tensorboard-2.14.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.14.0
#     Uninstalling tensorflow-2.14.0:
#       Successfully uninstalled tensorflow-2.14.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-text 2.14.0 requires tensorflow<2.15,>=2.14.0; platform_machine != "arm64" or platform_system != "Darwin", but you have tensorflow 2.12.0 which is incompatible.
# tf-models-official 2.14.0 requires tensorflow~=2.14.0, but you have tensorflow 2.12.0 which is incompatible.
# Successfully installed keras-2.12.0 tensorboard-2.12.3 tensorflow-2.12.0 tensorflow-estimator-2.12.0

# %%
# Install the Object Detection API
# %%bash
cd models/research/
protoc object_detection/protos/*.proto --python_out=.
cp object_detection/packages/tf2/setup.py .
python -m pip install .
# Out:
# Processing /content/models/research
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting avro-python3 (from object-detection==0.1)
#   Downloading avro-python3-1.10.2.tar.gz (38 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting apache-beam (from object-detection==0.1)
#   Downloading apache_beam-2.50.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 67.3 MB/s eta 0:00:00
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (9.4.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (4.9.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (3.7.1)
# Requirement already satisfied: Cython in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (3.0.3)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (21.6.0)
# Requirement already satisfied: tf-slim in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (1.16.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (2.0.7)
# Collecting lvis (from object-detection==0.1)
#   Downloading lvis-0.5.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (1.11.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (1.5.3)
# Collecting tf-models-official>=2.5.1 (from object-detection==0.1)
#   Downloading tf_models_official-2.14.0-py2.py3-none-any.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 79.4 MB/s eta 0:00:00
# Collecting tensorflow_io (from object-detection==0.1)
#   Downloading tensorflow_io-0.34.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (28.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.8/28.8 MB 44.6 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (2.13.1)
# Collecting pyparsing==2.4.7 (from object-detection==0.1)
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 10.2 MB/s eta 0:00:00
# Collecting sacrebleu<=2.2.0 (from object-detection==0.1)
#   Downloading sacrebleu-2.2.0-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.6/116.6 kB 16.4 MB/s eta 0:00:00
# Collecting portalocker (from sacrebleu<=2.2.0->object-detection==0.1)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2023.6.3)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (1.23.5)
# Collecting colorama (from sacrebleu<=2.2.0->object-detection==0.1)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: gin-config in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.84.0)
# Collecting immutabledict (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading immutabledict-3.0.0-py3-none-any.whl (4.0 kB)
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.5.16)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.1.3)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.8.1.78)
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.9.5)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (9.0.0)
# Requirement already satisfied: pyyaml>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (6.0.1)
# Collecting sentencepiece (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 61.2 MB/s eta 0:00:00
# Collecting seqeval (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 5.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.9.3)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.15.0)
# Collecting tensorflow-model-optimization>=0.4.1 (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading tensorflow_model_optimization-0.7.5-py2.py3-none-any.whl (241 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.2/241.2 kB 27.9 MB/s eta 0:00:00
# Collecting tensorflow-text~=2.14.0 (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading tensorflow_text-2.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 81.1 MB/s eta 0:00:00
# Collecting tensorflow~=2.14.0 (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading tensorflow-2.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (489.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 489.8/489.8 MB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->object-detection==0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->object-detection==0.1) (2023.3.post1)
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from tf-slim->object-detection==0.1) (1.4.0)
# Collecting crcmod<2.0,>=1.7 (from apache-beam->object-detection==0.1)
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 16.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting orjson<4.0 (from apache-beam->object-detection==0.1)
#   Downloading orjson-3.9.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 20.6 MB/s eta 0:00:00
# Collecting dill<0.3.2,>=0.3.1.1 (from apache-beam->object-detection==0.1)
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.0/152.0 kB 23.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: cloudpickle~=2.2.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (2.2.1)
# Collecting fastavro<2,>=0.23.6 (from apache-beam->object-detection==0.1)
#   Downloading fastavro-1.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 86.2 MB/s eta 0:00:00
# Collecting fasteners<1.0,>=0.3 (from apache-beam->object-detection==0.1)
#   Downloading fasteners-0.19-py3-none-any.whl (18 kB)
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (1.59.0)
# Collecting hdfs<3.0.0,>=2.1.0 (from apache-beam->object-detection==0.1)
#   Downloading hdfs-2.7.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.4/43.4 kB 6.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (0.22.0)
# Collecting objsize<0.7.0,>=0.6.1 (from apache-beam->object-detection==0.1)
#   Downloading objsize-0.6.1-py3-none-any.whl (9.3 kB)
# Collecting pymongo<5.0.0,>=3.8.0 (from apache-beam->object-detection==0.1)
#   Downloading pymongo-4.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (671 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 671.3/671.3 kB 41.7 MB/s eta 0:00:00
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (1.22.3)
# Requirement already satisfied: protobuf<4.24.0,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (3.20.3)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (1.4.2)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (4.5.0)
# Collecting zstandard<1,>=0.18.0 (from apache-beam->object-detection==0.1)
#   Downloading zstandard-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 76.8 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow<12.0.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (9.0.0)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from lvis->object-detection==0.1) (0.12.0)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from lvis->object-detection==0.1) (1.4.5)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.10/dist-packages (from lvis->object-detection==0.1) (4.8.0.76)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->object-detection==0.1) (1.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->object-detection==0.1) (4.43.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->object-detection==0.1) (23.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.34.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_io->object-detection==0.1) (0.34.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.17.3)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.11.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.1.1)
# Collecting docopt (from hdfs<3.0.0,>=2.1.0->apache-beam->object-detection==0.1)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2023.7.22)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (4.66.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2.0.6)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (6.0.0)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo<5.0.0,>=3.8.0->apache-beam->object-detection==0.1)
#   Downloading dnspython-2.4.2-py3-none-any.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 30.5 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (3.4)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.14.0->tf-models-official>=2.5.1->object-detection==0.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.14.0->tf-models-official>=2.5.1->object-detection==0.1) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.14.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.14.0->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.14.0->tf-models-official>=2.5.1->object-detection==0.1) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.14.0->tf-models-official>=2.5.1->object-detection==0.1) (16.0.6)
# Collecting ml-dtypes==0.2.0 (from tensorflow~=2.14.0->tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 63.6 MB/s eta 0:00:00
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.14.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.14.0->tf-models-official>=2.5.1->object-detection==0.1) (67.7.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.14.0->tf-models-official>=2.5.1->object-detection==0.1) (2.3.0)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow~=2.14.0->tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 10.8 MB/s eta 0:00:00
# Collecting tensorboard<2.15,>=2.14 (from tensorflow~=2.14.0->tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading tensorboard-2.14.1-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 79.6 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.15,>=2.14.0 (from tensorflow~=2.14.0->tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading tensorflow_estimator-2.14.0-py2.py3-none-any.whl (440 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.7/440.7 kB 35.4 MB/s eta 0:00:00
# Collecting keras (from object-detection==0.1)
#   Downloading keras-2.14.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 68.8 MB/s eta 0:00:00
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official>=2.5.1->object-detection==0.1) (0.1.8)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.3.0)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (4.9)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.2.2)
# Requirement already satisfied: array-record in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.4.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (8.1.7)
# Requirement already satisfied: etils[enp,epath,etree]>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.5.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (2.3)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.14.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.10.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow~=2.14.0->tf-models-official>=2.5.1->object-detection==0.1) (0.41.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (2023.6.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (6.1.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (3.17.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.60.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (5.3.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (3.2.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow~=2.14.0->tf-models-official>=2.5.1->object-detection==0.1) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow~=2.14.0->tf-models-official>=2.5.1->object-detection==0.1) (3.4.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow~=2.14.0->tf-models-official>=2.5.1->object-detection==0.1) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow~=2.14.0->tf-models-official>=2.5.1->object-detection==0.1) (3.0.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow~=2.14.0->tf-models-official>=2.5.1->object-detection==0.1) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow~=2.14.0->tf-models-official>=2.5.1->object-detection==0.1) (2.1.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow~=2.14.0->tf-models-official>=2.5.1->object-detection==0.1) (3.2.2)
# Building wheels for collected packages: object-detection, avro-python3, crcmod, dill, hdfs, seqeval, docopt
#   Building wheel for object-detection (setup.py): started
#   Building wheel for object-detection (setup.py): finished with status 'done'
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1697354 sha256=58cf961dc62e3e8eb8f3d28568a4c245f2e0da1625994d7d2f97d328d35501da
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jhm3l6yy/wheels/53/dd/70/2de274d6c443c69d367bd6a5606f95e5a6df61aacf1435ec0d
#   Building wheel for avro-python3 (setup.py): started
#   Building wheel for avro-python3 (setup.py): finished with status 'done'
#   Created wheel for avro-python3: filename=avro_python3-1.10.2-py3-none-any.whl size=43991 sha256=e04658a06152f8bb8ab84aa7913df9043709fc692a5eb8dba79c0571a8f7027d
#   Stored in directory: /root/.cache/pip/wheels/bc/85/62/6cdd81c56f923946b401cecff38055b94c9b766927f7d8ca82
#   Building wheel for crcmod (setup.py): started
#   Building wheel for crcmod (setup.py): finished with status 'done'
#   Created wheel for crcmod: filename=crcmod-1.7-cp310-cp310-linux_x86_64.whl size=31407 sha256=aa52f1be5277dfaf28cfe50b4b05b7523d79fbc4d532c6eb095325a9ba614bd7
#   Stored in directory: /root/.cache/pip/wheels/85/4c/07/72215c529bd59d67e3dac29711d7aba1b692f543c808ba9e86
#   Building wheel for dill (setup.py): started
#   Building wheel for dill (setup.py): finished with status 'done'
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78542 sha256=23c7e319b25ae313cb3ebb49a6f91ab7c11558209ec3496ea10a70492715b570
#   Stored in directory: /root/.cache/pip/wheels/ea/e2/86/64980d90e297e7bf2ce588c2b96e818f5399c515c4bb8a7e4f
#   Building wheel for hdfs (setup.py): started
#   Building wheel for hdfs (setup.py): finished with status 'done'
#   Created wheel for hdfs: filename=hdfs-2.7.2-py3-none-any.whl size=34168 sha256=0936805f6b6e3cb6a14659886bc113314109deb64050bc26556a19a53aaacba4
#   Stored in directory: /root/.cache/pip/wheels/ab/39/8e/e1905de9af8ae74911cd3e53e721995cd230816f63776e5825
#   Building wheel for seqeval (setup.py): started
#   Building wheel for seqeval (setup.py): finished with status 'done'
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=d191a64b12ee1198b9be766c2d26f7b02b92826b8831a8114d663fd8659056e8
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
#   Building wheel for docopt (setup.py): started
#   Building wheel for docopt (setup.py): finished with status 'done'
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13705 sha256=2803d5049409f2735518cde853d45f48a5cb14c7e312a7af700dff044d163f8c
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built object-detection avro-python3 crcmod dill hdfs seqeval docopt
# Installing collected packages: sentencepiece, docopt, crcmod, zstandard, wrapt, tensorflow-model-optimization, tensorflow_io, tensorflow-estimator, pyparsing, portalocker, orjson, objsize, ml-dtypes, keras, immutabledict, fasteners, fastavro, dnspython, dill, colorama, avro-python3, sacrebleu, pymongo, hdfs, seqeval, lvis, apache-beam, tensorboard, tensorflow, tensorflow-text, tf-models-official, object-detection
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.15.0
#     Uninstalling wrapt-1.15.0:
#       Successfully uninstalled wrapt-1.15.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.13.0
#     Uninstalling tensorflow-estimator-2.13.0:
#       Successfully uninstalled tensorflow-estimator-2.13.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.3.1
#     Uninstalling ml-dtypes-0.3.1:
#       Successfully uninstalled ml-dtypes-0.3.1
#   Attempting uninstall: keras
#     Found existing installation: keras 2.13.1
#     Uninstalling keras-2.13.1:
#       Successfully uninstalled keras-2.13.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.13.0
#     Uninstalling tensorboard-2.13.0:
#       Successfully uninstalled tensorboard-2.13.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.13.0
#     Uninstalling tensorflow-2.13.0:
#       Successfully uninstalled tensorflow-2.13.0
# Successfully installed apache-beam-2.50.0 avro-python3-1.10.2 colorama-0.4.6 crcmod-1.7 dill-0.3.1.1 dnspython-2.4.2 docopt-0.6.2 fastavro-1.8.4 fasteners-0.19 hdfs-2.7.2 immutabledict-3.0.0 keras-2.14.0 lvis-0.5.3 ml-dtypes-0.2.0 object-detection-0.1 objsize-0.6.1 orjson-3.9.8 portalocker-2.8.2 pymongo-4.5.0 pyparsing-2.4.7 sacrebleu-2.2.0 sentencepiece-0.1.99 seqeval-1.2.2 tensorboard-2.14.1 tensorflow-2.14.0 tensorflow-estimator-2.14.0 tensorflow-model-optimization-0.7.5 tensorflow-text-2.14.0 tensorflow_io-0.34.0 tf-models-official-2.14.0 wrapt-1.14.1 zstandard-0.21.0

# %%
import matplotlib
import matplotlib.pyplot as plt

import os
import random
import io
import imageio
import glob
import scipy.misc
import numpy as np
from six import BytesIO
from PIL import Image, ImageDraw, ImageFont
from IPython.display import display, Javascript
from IPython.display import Image as IPyImage

import tensorflow as tf

from object_detection.utils import label_map_util
from object_detection.utils import config_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.utils import colab_utils
from object_detection.builders import model_builder

# %matplotlib inline

# %%
#run model builder test
# !python /content/models/research/object_detection/builders/model_builder_tf2_test.py
# Out:
# 2023-10-11 07:54:56.603262: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-11 07:54:56.603317: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-11 07:54:56.603371: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-11 07:54:58.258707: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Running tests under Python 3.10.12: /usr/bin/python3
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2023-10-11 07:55:02.860654: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W1011 07:55:02.889808 135789379354624 batch_normalization.py:1531] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W1011 07:55:03.333314 135789379354624 model_builder.py:1112] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 2.15s
# I1011 07:55:03.796245 135789379354624 test_util.py:2472] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 2.15s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.66s
# I1011 07:55:04.454602 135789379354624 test_util.py:2472] time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.66s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.32s
# I1011 07:55:04.776819 135789379354624 test_util.py:2472] time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.32s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.31s
# I1011 07:55:05.090735 135789379354624 test_util.py:2472] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.31s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 2.23s
# I1011 07:55:07.317547 135789379354624 test_util.py:2472] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 2.23s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I1011 07:55:07.323888 135789379354624 test_util.py:2472] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.03s
# I1011 07:55:07.349595 135789379354624 test_util.py:2472] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.03s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.02s
# I1011 07:55:07.366534 135789379354624 test_util.py:2472] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.02s
# I1011 07:55:07.387119 135789379354624 test_util.py:2472] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.11s
# I1011 07:55:07.502131 135789379354624 test_util.py:2472] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.11s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.1s
# I1011 07:55:07.606590 135789379354624 test_util.py:2472] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.1s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.11s
# I1011 07:55:07.714338 135789379354624 test_util.py:2472] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.11s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.11s
# I1011 07:55:07.823587 135789379354624 test_util.py:2472] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.11s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.21s
# I1011 07:55:08.029308 135789379354624 test_util.py:2472] time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.21s
# [       OK ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.07s
# I1011 07:55:08.104909 135789379354624 test_util.py:2472] time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.07s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# I1011 07:55:08.448913 135789379354624 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b0
# I1011 07:55:08.449141 135789379354624 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 64
# I1011 07:55:08.449239 135789379354624 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 3
# I1011 07:55:08.453507 135789379354624 efficientnet_model.py:143] round_filter input=32 output=32
# I1011 07:55:08.499561 135789379354624 efficientnet_model.py:143] round_filter input=32 output=32
# I1011 07:55:08.499733 135789379354624 efficientnet_model.py:143] round_filter input=16 output=16
# I1011 07:55:08.614751 135789379354624 efficientnet_model.py:143] round_filter input=16 output=16
# I1011 07:55:08.614939 135789379354624 efficientnet_model.py:143] round_filter input=24 output=24
# I1011 07:55:08.920004 135789379354624 efficientnet_model.py:143] round_filter input=24 output=24
# I1011 07:55:08.920214 135789379354624 efficientnet_model.py:143] round_filter input=40 output=40
# I1011 07:55:09.242587 135789379354624 efficientnet_model.py:143] round_filter input=40 output=40
# I1011 07:55:09.242783 135789379354624 efficientnet_model.py:143] round_filter input=80 output=80
# I1011 07:55:09.781869 135789379354624 efficientnet_model.py:143] round_filter input=80 output=80
# I1011 07:55:09.782071 135789379354624 efficientnet_model.py:143] round_filter input=112 output=112
# I1011 07:55:10.710471 135789379354624 efficientnet_model.py:143] round_filter input=112 output=112
# I1011 07:55:10.710665 135789379354624 efficientnet_model.py:143] round_filter input=192 output=192
# I1011 07:55:11.916317 135789379354624 efficientnet_model.py:143] round_filter input=192 output=192
# I1011 07:55:11.916526 135789379354624 efficientnet_model.py:143] round_filter input=320 output=320
# I1011 07:55:12.285876 135789379354624 efficientnet_model.py:143] round_filter input=1280 output=1280
# I1011 07:55:12.431144 135789379354624 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1011 07:55:12.670047 135789379354624 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b1
# I1011 07:55:12.670265 135789379354624 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 88
# I1011 07:55:12.670358 135789379354624 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 4
# I1011 07:55:12.673859 135789379354624 efficientnet_model.py:143] round_filter input=32 output=32
# I1011 07:55:12.751161 135789379354624 efficientnet_model.py:143] round_filter input=32 output=32
# I1011 07:55:12.753519 135789379354624 efficientnet_model.py:143] round_filter input=16 output=16
# I1011 07:55:13.245539 135789379354624 efficientnet_model.py:143] round_filter input=16 output=16
# I1011 07:55:13.249912 135789379354624 efficientnet_model.py:143] round_filter input=24 output=24
# I1011 07:55:14.030056 135789379354624 efficientnet_model.py:143] round_filter input=24 output=24
# I1011 07:55:14.031445 135789379354624 efficientnet_model.py:143] round_filter input=40 output=40
# I1011 07:55:15.030555 135789379354624 efficientnet_model.py:143] round_filter input=40 output=40
# I1011 07:55:15.030765 135789379354624 efficientnet_model.py:143] round_filter input=80 output=80
# I1011 07:55:16.385797 135789379354624 efficientnet_model.py:143] round_filter input=80 output=80
# I1011 07:55:16.385994 135789379354624 efficientnet_model.py:143] round_filter input=112 output=112
# I1011 07:55:18.292053 135789379354624 efficientnet_model.py:143] round_filter input=112 output=112
# I1011 07:55:18.292258 135789379354624 efficientnet_model.py:143] round_filter input=192 output=192
# I1011 07:55:18.972788 135789379354624 efficientnet_model.py:143] round_filter input=192 output=192
# I1011 07:55:18.972989 135789379354624 efficientnet_model.py:143] round_filter input=320 output=320
# I1011 07:55:19.255420 135789379354624 efficientnet_model.py:143] round_filter input=1280 output=1280
# I1011 07:55:19.306577 135789379354624 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.1, resolution=240, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1011 07:55:19.413916 135789379354624 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b2
# I1011 07:55:19.414111 135789379354624 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 112
# I1011 07:55:19.414200 135789379354624 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 5
# I1011 07:55:19.417190 135789379354624 efficientnet_model.py:143] round_filter input=32 output=32
# I1011 07:55:19.444061 135789379354624 efficientnet_model.py:143] round_filter input=32 output=32
# I1011 07:55:19.444205 135789379354624 efficientnet_model.py:143] round_filter input=16 output=16
# I1011 07:55:19.655611 135789379354624 efficientnet_model.py:143] round_filter input=16 output=16
# I1011 07:55:19.655802 135789379354624 efficientnet_model.py:143] round_filter input=24 output=24
# I1011 07:55:20.060398 135789379354624 efficientnet_model.py:143] round_filter input=24 output=24
# I1011 07:55:20.060613 135789379354624 efficientnet_model.py:143] round_filter input=40 output=48
# I1011 07:55:20.496074 135789379354624 efficientnet_model.py:143] round_filter input=40 output=48
# I1011 07:55:20.496271 135789379354624 efficientnet_model.py:143] round_filter input=80 output=88
# I1011 07:55:21.043307 135789379354624 efficientnet_model.py:143] round_filter input=80 output=88
# I1011 07:55:21.043532 135789379354624 efficientnet_model.py:143] round_filter input=112 output=120
# I1011 07:55:21.593688 135789379354624 efficientnet_model.py:143] round_filter input=112 output=120
# I1011 07:55:21.593889 135789379354624 efficientnet_model.py:143] round_filter input=192 output=208
# I1011 07:55:22.268889 135789379354624 efficientnet_model.py:143] round_filter input=192 output=208
# I1011 07:55:22.269081 135789379354624 efficientnet_model.py:143] round_filter input=320 output=352
# I1011 07:55:22.573872 135789379354624 efficientnet_model.py:143] round_filter input=1280 output=1408
# I1011 07:55:22.629372 135789379354624 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.1, depth_coefficient=1.2, resolution=260, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1011 07:55:22.735330 135789379354624 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b3
# I1011 07:55:22.735524 135789379354624 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 160
# I1011 07:55:22.735613 135789379354624 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 6
# I1011 07:55:22.738994 135789379354624 efficientnet_model.py:143] round_filter input=32 output=40
# I1011 07:55:22.769810 135789379354624 efficientnet_model.py:143] round_filter input=32 output=40
# I1011 07:55:22.769965 135789379354624 efficientnet_model.py:143] round_filter input=16 output=24
# I1011 07:55:22.999735 135789379354624 efficientnet_model.py:143] round_filter input=16 output=24
# I1011 07:55:22.999927 135789379354624 efficientnet_model.py:143] round_filter input=24 output=32
# I1011 07:55:23.370356 135789379354624 efficientnet_model.py:143] round_filter input=24 output=32
# I1011 07:55:23.370511 135789379354624 efficientnet_model.py:143] round_filter input=40 output=48
# I1011 07:55:23.629066 135789379354624 efficientnet_model.py:143] round_filter input=40 output=48
# I1011 07:55:23.629226 135789379354624 efficientnet_model.py:143] round_filter input=80 output=96
# I1011 07:55:24.074939 135789379354624 efficientnet_model.py:143] round_filter input=80 output=96
# I1011 07:55:24.075103 135789379354624 efficientnet_model.py:143] round_filter input=112 output=136
# I1011 07:55:24.518262 135789379354624 efficientnet_model.py:143] round_filter input=112 output=136
# I1011 07:55:24.518437 135789379354624 efficientnet_model.py:143] round_filter input=192 output=232
# I1011 07:55:25.067596 135789379354624 efficientnet_model.py:143] round_filter input=192 output=232
# I1011 07:55:25.067757 135789379354624 efficientnet_model.py:143] round_filter input=320 output=384
# I1011 07:55:25.265785 135789379354624 efficientnet_model.py:143] round_filter input=1280 output=1536
# I1011 07:55:25.305336 135789379354624 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.2, depth_coefficient=1.4, resolution=300, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1011 07:55:25.376999 135789379354624 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b4
# I1011 07:55:25.377151 135789379354624 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 224
# I1011 07:55:25.377230 135789379354624 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 7
# I1011 07:55:25.379185 135789379354624 efficientnet_model.py:143] round_filter input=32 output=48
# I1011 07:55:25.398952 135789379354624 efficientnet_model.py:143] round_filter input=32 output=48
# I1011 07:55:25.399091 135789379354624 efficientnet_model.py:143] round_filter input=16 output=24
# I1011 07:55:25.548861 135789379354624 efficientnet_model.py:143] round_filter input=16 output=24
# I1011 07:55:25.549016 135789379354624 efficientnet_model.py:143] round_filter input=24 output=32
# I1011 07:55:25.894854 135789379354624 efficientnet_model.py:143] round_filter input=24 output=32
# I1011 07:55:25.895009 135789379354624 efficientnet_model.py:143] round_filter input=40 output=56
# I1011 07:55:26.258831 135789379354624 efficientnet_model.py:143] round_filter input=40 output=56
# I1011 07:55:26.259007 135789379354624 efficientnet_model.py:143] round_filter input=80 output=112
# I1011 07:55:26.803794 135789379354624 efficientnet_model.py:143] round_filter input=80 output=112
# I1011 07:55:26.803989 135789379354624 efficientnet_model.py:143] round_filter input=112 output=160
# I1011 07:55:27.626139 135789379354624 efficientnet_model.py:143] round_filter input=112 output=160
# I1011 07:55:27.626303 135789379354624 efficientnet_model.py:143] round_filter input=192 output=272
# I1011 07:55:28.359565 135789379354624 efficientnet_model.py:143] round_filter input=192 output=272
# I1011 07:55:28.359725 135789379354624 efficientnet_model.py:143] round_filter input=320 output=448
# I1011 07:55:28.555318 135789379354624 efficientnet_model.py:143] round_filter input=1280 output=1792
# I1011 07:55:28.593839 135789379354624 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.4, depth_coefficient=1.8, resolution=380, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1011 07:55:28.675719 135789379354624 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b5
# I1011 07:55:28.675879 135789379354624 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 288
# I1011 07:55:28.675952 135789379354624 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 7
# I1011 07:55:28.677808 135789379354624 efficientnet_model.py:143] round_filter input=32 output=48
# I1011 07:55:28.697045 135789379354624 efficientnet_model.py:143] round_filter input=32 output=48
# I1011 07:55:28.697158 135789379354624 efficientnet_model.py:143] round_filter input=16 output=24
# I1011 07:55:28.922290 135789379354624 efficientnet_model.py:143] round_filter input=16 output=24
# I1011 07:55:28.922487 135789379354624 efficientnet_model.py:143] round_filter input=24 output=40
# I1011 07:55:29.364482 135789379354624 efficientnet_model.py:143] round_filter input=24 output=40
# I1011 07:55:29.364638 135789379354624 efficientnet_model.py:143] round_filter input=40 output=64
# I1011 07:55:29.812875 135789379354624 efficientnet_model.py:143] round_filter input=40 output=64
# I1011 07:55:29.813046 135789379354624 efficientnet_model.py:143] round_filter input=80 output=128
# I1011 07:55:30.445230 135789379354624 efficientnet_model.py:143] round_filter input=80 output=128
# I1011 07:55:30.445410 135789379354624 efficientnet_model.py:143] round_filter input=112 output=176
# I1011 07:55:31.061598 135789379354624 efficientnet_model.py:143] round_filter input=112 output=176
# I1011 07:55:31.061759 135789379354624 efficientnet_model.py:143] round_filter input=192 output=304
# I1011 07:55:31.851585 135789379354624 efficientnet_model.py:143] round_filter input=192 output=304
# I1011 07:55:31.851745 135789379354624 efficientnet_model.py:143] round_filter input=320 output=512
# I1011 07:55:32.140278 135789379354624 efficientnet_model.py:143] round_filter input=1280 output=2048
# I1011 07:55:32.180068 135789379354624 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.6, depth_coefficient=2.2, resolution=456, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1011 07:55:32.274380 135789379354624 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b6
# I1011 07:55:32.274549 135789379354624 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 384
# I1011 07:55:32.274627 135789379354624 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 8
# I1011 07:55:32.276552 135789379354624 efficientnet_model.py:143] round_filter input=32 output=56
# I1011 07:55:32.295802 135789379354624 efficientnet_model.py:143] round_filter input=32 output=56
# I1011 07:55:32.295920 135789379354624 efficientnet_model.py:143] round_filter input=16 output=32
# I1011 07:55:32.513290 135789379354624 efficientnet_model.py:143] round_filter input=16 output=32
# I1011 07:55:32.513456 135789379354624 efficientnet_model.py:143] round_filter input=24 output=40
# I1011 07:55:33.059566 135789379354624 efficientnet_model.py:143] round_filter input=24 output=40
# I1011 07:55:33.059727 135789379354624 efficientnet_model.py:143] round_filter input=40 output=72
# I1011 07:55:33.735760 135789379354624 efficientnet_model.py:143] round_filter input=40 output=72
# I1011 07:55:33.735952 135789379354624 efficientnet_model.py:143] round_filter input=80 output=144
# I1011 07:55:34.758121 135789379354624 efficientnet_model.py:143] round_filter input=80 output=144
# I1011 07:55:34.758323 135789379354624 efficientnet_model.py:143] round_filter input=112 output=200
# I1011 07:55:35.824305 135789379354624 efficientnet_model.py:143] round_filter input=112 output=200
# I1011 07:55:35.824514 135789379354624 efficientnet_model.py:143] round_filter input=192 output=344
# I1011 07:55:37.637346 135789379354624 efficientnet_model.py:143] round_filter input=192 output=344
# I1011 07:55:37.637578 135789379354624 efficientnet_model.py:143] round_filter input=320 output=576
# I1011 07:55:38.050650 135789379354624 efficientnet_model.py:143] round_filter input=1280 output=2304
# I1011 07:55:38.110061 135789379354624 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1011 07:55:38.291658 135789379354624 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b7
# I1011 07:55:38.291862 135789379354624 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 384
# I1011 07:55:38.291961 135789379354624 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 8
# I1011 07:55:38.294993 135789379354624 efficientnet_model.py:143] round_filter input=32 output=64
# I1011 07:55:38.325963 135789379354624 efficientnet_model.py:143] round_filter input=32 output=64
# I1011 07:55:38.326126 135789379354624 efficientnet_model.py:143] round_filter input=16 output=32
# I1011 07:55:38.767150 135789379354624 efficientnet_model.py:143] round_filter input=16 output=32
# I1011 07:55:38.767375 135789379354624 efficientnet_model.py:143] round_filter input=24 output=48
# I1011 07:55:39.761012 135789379354624 efficientnet_model.py:143] round_filter input=24 output=48
# I1011 07:55:39.761224 135789379354624 efficientnet_model.py:143] round_filter input=40 output=80
# I1011 07:55:40.699138 135789379354624 efficientnet_model.py:143] round_filter input=40 output=80
# I1011 07:55:40.699337 135789379354624 efficientnet_model.py:143] round_filter input=80 output=160
# I1011 07:55:42.040245 135789379354624 efficientnet_model.py:143] round_filter input=80 output=160
# I1011 07:55:42.040464 135789379354624 efficientnet_model.py:143] round_filter input=112 output=224
# I1011 07:55:43.393409 135789379354624 efficientnet_model.py:143] round_filter input=112 output=224
# I1011 07:55:43.393614 135789379354624 efficientnet_model.py:143] round_filter input=192 output=384
# I1011 07:55:45.154196 135789379354624 efficientnet_model.py:143] round_filter input=192 output=384
# I1011 07:55:45.154419 135789379354624 efficientnet_model.py:143] round_filter input=320 output=640
# I1011 07:55:45.629787 135789379354624 efficientnet_model.py:143] round_filter input=1280 output=2560
# I1011 07:55:45.667510 135789379354624 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 37.69s
# I1011 07:55:45.793643 135789379354624 test_util.py:2472] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 37.69s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I1011 07:55:45.823122 135789379354624 test_util.py:2472] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I1011 07:55:45.824849 135789379354624 test_util.py:2472] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I1011 07:55:45.825336 135789379354624 test_util.py:2472] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I1011 07:55:45.826944 135789379354624 test_util.py:2472] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I1011 07:55:45.828286 135789379354624 test_util.py:2472] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I1011 07:55:45.828746 135789379354624 test_util.py:2472] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I1011 07:55:45.829763 135789379354624 test_util.py:2472] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 44.181s
#
# OK (skipped=1)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="C7t6SWdiPn9568uwJat9")
project = rf.workspace("safe-bite").project("safe-bite-2")
dataset = project.version(1).download("tfrecord")
# Out:
# Requirement already satisfied: roboflow in /usr/local/lib/python3.10/dist-packages (1.1.7)
# Requirement already satisfied: certifi==2022.12.7 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2022.12.7)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.0.0)
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.10.0)
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.10)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.23.5)
# Requirement already satisfied: opencv-python-headless==4.8.0.74 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.8.0.74)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Requirement already satisfied: pyparsing==2.4.7 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.4.7)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Requirement already satisfied: supervision in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.15.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.0.6)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.1)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.43.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.3.0)
# Requirement already satisfied: scipy<2.0.0,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from supervision->roboflow) (1.11.3)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Safe-Bite-2-1 to tfrecord:: 100%|██████████| 89274/89274 [00:04<00:00, 18262.04it/s]
# Extracting Dataset Version Zip to Safe-Bite-2-1 in tfrecord:: 100%|██████████| 8/8 [00:00<00:00, 21.72it/s]

# %%
# NOTE: Update these TFRecord names from "cells" and "cells_label_map" to your files!
test_record_fname = dataset.location + '/test/Nutrition-Table-and-Ingredients.tfrecord'
train_record_fname = dataset.location + '/train/Nutrition-Table-and-Ingredients.tfrecord'
label_map_pbtxt_fname = dataset.location + '/train/Nutrition-Table-and-Ingredients_label_map.pbtxt'

# %%
##change chosen model to deploy different models available in the TF2 object detection zoo
MODELS_CONFIG = {
    'efficientdet-d0': {
        'model_name': 'efficientdet_d0_coco17_tpu-32',
        'base_pipeline_file': 'ssd_efficientdet_d0_512x512_coco17_tpu-8.config',
        'pretrained_checkpoint': 'efficientdet_d0_coco17_tpu-32.tar.gz',
        'batch_size': 10
    },
    'efficientdet-d1': {
        'model_name': 'efficientdet_d1_coco17_tpu-32',
        'base_pipeline_file': 'ssd_efficientdet_d1_640x640_coco17_tpu-8.config',
        'pretrained_checkpoint': 'efficientdet_d1_coco17_tpu-32.tar.gz',
        'batch_size': 10
    },
    'efficientdet-d2': {
        'model_name': 'efficientdet_d2_coco17_tpu-32',
        'base_pipeline_file': 'ssd_efficientdet_d2_768x768_coco17_tpu-8.config',
        'pretrained_checkpoint': 'efficientdet_d2_coco17_tpu-32.tar.gz',
        'batch_size': 10
    },
        'efficientdet-d3': {
        'model_name': 'efficientdet_d3_coco17_tpu-32',
        'base_pipeline_file': 'ssd_efficientdet_d3_896x896_coco17_tpu-32.config',
        'pretrained_checkpoint': 'efficientdet_d3_coco17_tpu-32.tar.gz',
        'batch_size': 10
    }
}

#in this tutorial we implement the lightweight, smallest state of the art efficientdet model
#if you want to scale up tot larger efficientdet models you will likely need more compute!
chosen_model = 'efficientdet-d0'

num_steps = 25000 #The more steps, the longer the training. Increase if your loss function is still decreasing and validation metrics are increasing.
num_eval_steps = 400 #Perform evaluation after so many steps

model_name = MODELS_CONFIG[chosen_model]['model_name']
pretrained_checkpoint = MODELS_CONFIG[chosen_model]['pretrained_checkpoint']
base_pipeline_file = MODELS_CONFIG[chosen_model]['base_pipeline_file']
batch_size = MODELS_CONFIG[chosen_model]['batch_size'] #if you can fit a large batch in memory, it may speed up your training

# %%
#download pretrained weights
# %mkdir /content/models/research/deploy/
# %cd /content/models/research/deploy/
import tarfile
download_tar = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/' + pretrained_checkpoint

# !wget {download_tar}
tar = tarfile.open(pretrained_checkpoint)
tar.extractall()
tar.close()
# Out:
# mkdir: cannot create directory ‘/content/models/research/deploy/’: File exists
# /content/models/research/deploy
# --2023-10-11 10:45:15--  http://download.tensorflow.org/models/object_detection/tf2/20200711/efficientdet_d0_coco17_tpu-32.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 74.125.24.207, 142.250.4.207, 142.251.10.207, ...
# Connecting to download.tensorflow.org (download.tensorflow.org)|74.125.24.207|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30736482 (29M) [application/x-tar]
# Saving to: ‘efficientdet_d0_coco17_tpu-32.tar.gz.5’
#
# efficientdet_d0_coc 100%[===================>]  29.31M  11.4MB/s    in 2.6s
#
# 2023-10-11 10:45:18 (11.4 MB/s) - ‘efficientdet_d0_coco17_tpu-32.tar.gz.5’ saved [30736482/30736482]

# %%
#download base training configuration file
# %cd /content/models/research/deploy
download_config = 'https://raw.githubusercontent.com/tensorflow/models/master/research/object_detection/configs/tf2/' + base_pipeline_file
# !wget {download_config}
# Out:
# /content/models/research/deploy
# --2023-10-11 10:45:19--  https://raw.githubusercontent.com/tensorflow/models/master/research/object_detection/configs/tf2/ssd_efficientdet_d0_512x512_coco17_tpu-8.config
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4630 (4.5K) [text/plain]
# Saving to: ‘ssd_efficientdet_d0_512x512_coco17_tpu-8.config.5’
#
# ssd_efficientdet_d0 100%[===================>]   4.52K  --.-KB/s    in 0s
#
# 2023-10-11 10:45:19 (51.6 MB/s) - ‘ssd_efficientdet_d0_512x512_coco17_tpu-8.config.5’ saved [4630/4630]

# %%
os.listdir('/content/Safe-Bite-2-1/train/')
# Out:
# ['Nutrition-Table-and-Ingredients.tfrecord',
#  'Nutrition-Table-and-Ingredients_label_map.pbtxt']

# %%
#prepare
pipeline_fname = '/content/models/research/deploy/' + base_pipeline_file
fine_tune_checkpoint = '/content/models/research/deploy/' + model_name + '/checkpoint/ckpt-0'

def get_num_classes(pbtxt_fname):
    from object_detection.utils import label_map_util
    label_map = label_map_util.load_labelmap(pbtxt_fname)
    categories = label_map_util.convert_label_map_to_categories(
        label_map, max_num_classes=90, use_display_name=True)
    category_index = label_map_util.create_category_index(categories)
    return len(category_index.keys())
num_classes = get_num_classes(label_map_pbtxt_fname)

# %%
#write custom configuration file by slotting our dataset, model checkpoint, and training parameters into the base pipeline file

import re

# %cd /content/models/research/deploy
print('writing custom configuration file')

with open(pipeline_fname) as f:
    s = f.read()
with open('pipeline_file.config', 'w') as f:

    # fine_tune_checkpoint
    s = re.sub('fine_tune_checkpoint: ".*?"',
               'fine_tune_checkpoint: "{}"'.format(fine_tune_checkpoint), s)

    # tfrecord files train and test.
    s = re.sub(
        '(input_path: ".*?)(PATH_TO_BE_CONFIGURED/train)(.*?")', 'input_path: "{}"'.format(train_record_fname), s)
    s = re.sub(
        '(input_path: ".*?)(PATH_TO_BE_CONFIGURED/val)(.*?")', 'input_path: "{}"'.format(test_record_fname), s)

    # label_map_path
    s = re.sub(
        'label_map_path: ".*?"', 'label_map_path: "{}"'.format(label_map_pbtxt_fname), s)

    # Set training batch_size.
    s = re.sub('batch_size: [0-9]+',
               'batch_size: {}'.format(batch_size), s)

    # Set training steps, num_steps
    s = re.sub('num_steps: [0-9]+',
               'num_steps: {}'.format(num_steps), s)

    # Set number of classes num_classes.
    s = re.sub('num_classes: [0-9]+',
               'num_classes: {}'.format(num_classes), s)

    #fine-tune checkpoint type
    s = re.sub(
        'fine_tune_checkpoint_type: "classification"', 'fine_tune_checkpoint_type: "{}"'.format('detection'), s)

    f.write(s)
# Out:
# /content/models/research/deploy
# writing custom configuration file

# %%
# %cat /content/models/research/deploy/pipeline_file.config
# Out:
#  # SSD with EfficientNet-b0 + BiFPN feature extractor,
# # shared box predictor and focal loss (a.k.a EfficientDet-d0).
# # See EfficientDet, Tan et al, https://arxiv.org/abs/1911.09070
# # See Lin et al, https://arxiv.org/abs/1708.02002
# # Trained on COCO, initialized from an EfficientNet-b0 checkpoint.
# #
# # Train on TPU-8
#
# model {
#   ssd {
#     inplace_batchnorm_update: true
#     freeze_batchnorm: false
#     num_classes: 2
#     add_background_class: false
#     box_coder {
#       faster_rcnn_box_coder {
#         y_scale: 10.0
#         x_scale: 10.0
#         height_scale: 5.0
#         width_scale: 5.0
#       }
#     }
#     matcher {
#       argmax_matcher {
#         matched_threshold: 0.5
#         unmatched_threshold: 0.5
#         ignore_thresholds: false
#         negatives_lower_than_unmatched: true
#         force_match_for_each_row: true
#         use_matmul_gather: true
#       }
#     }
#     similarity_calculator {
#       iou_similarity {
#       }
#     }
#     encode_background_as_zeros: true
#     anchor_generator {
#       multiscale_anchor_generator {
#         min_level: 3
#         max_level: 7
#         anchor_scale: 4.0
#         aspect_ratios: [1.0, 2.0, 0.5]
#         scales_per_octave: 3
#       }
#     }
#     image_resizer {
#       keep_aspect_ratio_resizer {
#         min_dimension: 512
#         max_dimension: 512
#         pad_to_max_dimension: true
#         }
#     }
#     box_predictor {
#       weight_shared_convolutional_box_predictor {
#         depth: 64
#         class_prediction_bias_init: -4.6
#         conv_hyperparams {
#           force_use_bias: true
#           activation: SWISH
#           regularizer {
#             l2_regularizer {
#               weight: 0.00004
#             }
#           }
#           initializer {
#             random_normal_initializer {
#               stddev: 0.01
#               mean: 0.0
#             }
#           }
#           batch_norm {
#             scale: true
#             decay: 0.99
#             epsilon: 0.001
#           }
#         }
#         num_layers_before_predictor: 3
#         kernel_size: 3
#         use_depthwise: true
#       }
#     }
#     feature_extractor {
#       type: 'ssd_efficientnet-b0_bifpn_keras'
#       bifpn {
#         min_level: 3
#         max_level: 7
#         num_iterations: 3
#         num_filters: 64
#       }
#       conv_hyperparams {
#         force_use_bias: true
#         activation: SWISH
#         regularizer {
#           l2_regularizer {
#             weight: 0.00004
#           }
#         }
#         initializer {
#           truncated_normal_initializer {
#             stddev: 0.03
#             mean: 0.0
#           }
#         }
#         batch_norm {
#           scale: true,
#           decay: 0.99,
#           epsilon: 0.001,
#         }
#       }
#     }
#     loss {
#       classification_loss {
#         weighted_sigmoid_focal {
#           alpha: 0.25
#           gamma: 1.5
#         }
#       }
#       localization_loss {
#         weighted_smooth_l1 {
#         }
#       }
#       classification_weight: 1.0
#       localization_weight: 1.0
#     }
#     normalize_loss_by_num_matches: true
#     normalize_loc_loss_by_codesize: true
#     post_processing {
#       batch_non_max_suppression {
#         score_threshold: 1e-8
#         iou_threshold: 0.5
#         max_detections_per_class: 100
#         max_total_detections: 100
#       }
#       score_converter: SIGMOID
#     }
#   }
# }
#
# train_config: {
#   fine_tune_checkpoint: "/content/models/research/deploy/efficientdet_d0_coco17_tpu-32/checkpoint/ckpt-0"
#   fine_tune_checkpoint_version: V2
#   fine_tune_checkpoint_type: "detection"
#   batch_size: 10
#   sync_replicas: true
#   startup_delay_steps: 0
#   replicas_to_aggregate: 8
#   use_bfloat16: true
#   num_steps: 25000
#   data_augmentation_options {
#     random_horizontal_flip {
#     }
#   }
#   data_augmentation_options {
#     random_scale_crop_and_pad_to_square {
#       output_size: 512
#       scale_min: 0.1
#       scale_max: 2.0
#     }
#   }
#   optimizer {
#     momentum_optimizer: {
#       learning_rate: {
#         cosine_decay_learning_rate {
#           learning_rate_base: 8e-2
#           total_steps: 300000
#           warmup_learning_rate: .001
#           warmup_steps: 2500
#         }
#       }
#       momentum_optimizer_value: 0.9
#     }
#     use_moving_average: false
#   }
#   max_number_of_boxes: 100
#   unpad_groundtruth_tensors: false
# }
#
# train_input_reader: {
#   label_map_path: "/content/Safe-Bite-2-1/train/Nutrition-Table-and-Ingredients_label_map.pbtxt"
#   tf_record_input_reader {
#     input_path: "/content/Safe-Bite-2-1/train/Nutrition-Table-and-Ingredients.tfrecord"
#   }
# }
#
# eval_config: {
#   metrics_set: "coco_detection_metrics"
#   use_moving_averages: false
#   batch_size: 10;
# }
#
# eval_input_reader: {
#   label_map_path: "/content/Safe-Bite-2-1/train/Nutrition-Table-and-Ingredients_label_map.pbtxt"
#   shuffle: false
#   num_epochs: 1
#   tf_record_input_reader {
#     input_path: "/content/Safe-Bite-2-1/test/Nutrition-Table-and-Ingredients.tfrecord"
#   }
# }

# %%
pipeline_file = '/content/models/research/deploy/pipeline_file.config'
model_dir = '/content/training/'

# %%
# !cp /content/drive/MyDrive/Project-1/checkpoint /content/training
# !cp /content/drive/MyDrive/Project-1/ckpt-9.data-00000-of-00001 /content/training
# !cp /content/drive/MyDrive/Project-1/ckpt-8.data-00000-of-00001 /content/training
# !cp /content/drive/MyDrive/Project-1/ckpt-9.index /content/training

# %%
# !python /content/models/research/object_detection/model_main_tf2.py \
    --pipeline_config_path={pipeline_file} \
    --model_dir={model_dir} \
    --alsologtostderr \
    --num_train_steps={num_steps} \
    --sample_1_of_n_eval_examples=1 \
    --num_eval_steps={num_eval_steps}
# Out:
# 2023-10-11 10:45:42.857322: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-10-11 10:45:46.753701: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I1011 10:45:46.774629 139567239794688 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 25000
# I1011 10:45:46.778100 139567239794688 config_util.py:552] Maybe overwriting train_steps: 25000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I1011 10:45:46.778256 139567239794688 config_util.py:552] Maybe overwriting use_bfloat16: False
# I1011 10:45:46.788654 139567239794688 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b0
# I1011 10:45:46.788755 139567239794688 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 64
# I1011 10:45:46.788822 139567239794688 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 3
# I1011 10:45:46.948388 139567239794688 efficientnet_model.py:143] round_filter input=32 output=32
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1011 10:45:46.988199 139567239794688 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1011 10:45:46.992248 139567239794688 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1011 10:45:46.998537 139567239794688 efficientnet_model.py:143] round_filter input=32 output=32
# I1011 10:45:46.998636 139567239794688 efficientnet_model.py:143] round_filter input=16 output=16
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1011 10:45:47.021832 139567239794688 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1011 10:45:47.025704 139567239794688 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1011 10:45:47.101275 139567239794688 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1011 10:45:47.104778 139567239794688 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1011 10:45:47.110743 139567239794688 efficientnet_model.py:143] round_filter input=16 output=16
# I1011 10:45:47.110860 139567239794688 efficientnet_model.py:143] round_filter input=24 output=24
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1011 10:45:47.134649 139567239794688 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1011 10:45:47.137964 139567239794688 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1011 10:45:47.168183 139567239794688 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1011 10:45:47.171496 139567239794688 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1011 10:45:47.389594 139567239794688 efficientnet_model.py:143] round_filter input=24 output=24
# I1011 10:45:47.389737 139567239794688 efficientnet_model.py:143] round_filter input=40 output=40
# I1011 10:45:47.654985 139567239794688 efficientnet_model.py:143] round_filter input=40 output=40
# I1011 10:45:47.655166 139567239794688 efficientnet_model.py:143] round_filter input=80 output=80
# I1011 10:45:48.075875 139567239794688 efficientnet_model.py:143] round_filter input=80 output=80
# I1011 10:45:48.076039 139567239794688 efficientnet_model.py:143] round_filter input=112 output=112
# I1011 10:45:48.469388 139567239794688 efficientnet_model.py:143] round_filter input=112 output=112
# I1011 10:45:48.469555 139567239794688 efficientnet_model.py:143] round_filter input=192 output=192
# I1011 10:45:49.000286 139567239794688 efficientnet_model.py:143] round_filter input=192 output=192
# I1011 10:45:49.000528 139567239794688 efficientnet_model.py:143] round_filter input=320 output=320
# I1011 10:45:49.135480 139567239794688 efficientnet_model.py:143] round_filter input=1280 output=1280
# I1011 10:45:49.194545 139567239794688 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W1011 10:45:49.234551 139567239794688 deprecation.py:364] From /usr/local/lib/python3.10/dist-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['/content/Safe-Bite-2-1/train/Nutrition-Table-and-Ingredients.tfrecord']
# I1011 10:45:49.242191 139567239794688 dataset_builder.py:162] Reading unweighted datasets: ['/content/Safe-Bite-2-1/train/Nutrition-Table-and-Ingredients.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['/content/Safe-Bite-2-1/train/Nutrition-Table-and-Ingredients.tfrecord']
# I1011 10:45:49.242404 139567239794688 dataset_builder.py:79] Reading record datasets for input file: ['/content/Safe-Bite-2-1/train/Nutrition-Table-and-Ingredients.tfrecord']
# INFO:tensorflow:Number of filenames to read: 1
# I1011 10:45:49.242492 139567239794688 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W1011 10:45:49.242559 139567239794688 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W1011 10:45:49.249551 139567239794688 deprecation.py:364] From /usr/local/lib/python3.10/dist-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W1011 10:45:49.269816 139567239794688 deprecation.py:364] From /usr/local/lib/python3.10/dist-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W1011 10:45:59.000607 139567239794688 deprecation.py:364] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1011 10:46:04.456398 139567239794688 deprecation.py:364] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/object_detection/builders/optimizer_builder.py:124: The name tf.keras.optimizers.SGD is deprecated. Please use tf.keras.optimizers.legacy.SGD instead.
#
# W1011 10:46:06.504391 139567239794688 module_wrapper.py:149] From /usr/local/lib/python3.10/dist-packages/object_detection/builders/optimizer_builder.py:124: The name tf.keras.optimizers.SGD is deprecated. Please use tf.keras.optimizers.legacy.SGD instead.
#
# /usr/local/lib/python3.10/dist-packages/keras/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I1011 10:46:13.234446 139562262517312 api.py:459] feature_map_spatial_dims: [(64, 64), (32, 32), (16, 16), (8, 8), (4, 4)]
# I1011 10:46:30.832926 139562262517312 api.py:459] feature_map_spatial_dims: [(64, 64), (32, 32), (16, 16), (8, 8), (4, 4)]
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W1011 10:46:51.099972 139562361804352 deprecation.py:569] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# I1011 10:46:53.342825 139562361804352 api.py:459] feature_map_spatial_dims: [(64, 64), (32, 32), (16, 16), (8, 8), (4, 4)]
# WARNING:tensorflow:Gradients do not exist for variables ['top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# W1011 10:47:00.912925 139562361804352 utils.py:82] Gradients do not exist for variables ['top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# I1011 10:47:07.557338 139562361804352 api.py:459] feature_map_spatial_dims: [(64, 64), (32, 32), (16, 16), (8, 8), (4, 4)]
# WARNING:tensorflow:Gradients do not exist for variables ['top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# W1011 10:47:16.874390 139562361804352 utils.py:82] Gradients do not exist for variables ['top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# I1011 10:47:20.643546 139562361804352 api.py:459] feature_map_spatial_dims: [(64, 64), (32, 32), (16, 16), (8, 8), (4, 4)]
# WARNING:tensorflow:Gradients do not exist for variables ['top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# W1011 10:47:30.116826 139562361804352 utils.py:82] Gradients do not exist for variables ['top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# I1011 10:47:36.886813 139562361804352 api.py:459] feature_map_spatial_dims: [(64, 64), (32, 32), (16, 16), (8, 8), (4, 4)]
# WARNING:tensorflow:Gradients do not exist for variables ['top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# W1011 10:47:43.993155 139562361804352 utils.py:82] Gradients do not exist for variables ['top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2023-10-11 10:47:53.239803: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inEfficientDet-D0/model/stack_1/block_1/drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# INFO:tensorflow:Step 13100 per-step time 1.334s
# I1011 10:49:04.212180 139567239794688 model_lib_v2.py:705] Step 13100 per-step time 1.334s
# INFO:tensorflow:{'Loss/classification_loss': 0.1356724,
#  'Loss/localization_loss': 0.041004345,
#  'Loss/regularization_loss': 0.054038644,
#  'Loss/total_loss': 0.2307154,
#  'learning_rate': 0.079749666}
# I1011 10:49:04.212996 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.1356724,
#  'Loss/localization_loss': 0.041004345,
#  'Loss/regularization_loss': 0.054038644,
#  'Loss/total_loss': 0.2307154,
#  'learning_rate': 0.079749666}
# INFO:tensorflow:Step 13200 per-step time 0.540s
# I1011 10:49:58.220644 139567239794688 model_lib_v2.py:705] Step 13200 per-step time 0.540s
# INFO:tensorflow:{'Loss/classification_loss': 0.1755214,
#  'Loss/localization_loss': 0.08504696,
#  'Loss/regularization_loss': 0.054079168,
#  'Loss/total_loss': 0.31464756,
#  'learning_rate': 0.07974493}
# I1011 10:49:58.220973 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.1755214,
#  'Loss/localization_loss': 0.08504696,
#  'Loss/regularization_loss': 0.054079168,
#  'Loss/total_loss': 0.31464756,
#  'learning_rate': 0.07974493}
# INFO:tensorflow:Step 13300 per-step time 0.544s
# I1011 10:50:52.648298 139567239794688 model_lib_v2.py:705] Step 13300 per-step time 0.544s
# INFO:tensorflow:{'Loss/classification_loss': 0.11170105,
#  'Loss/localization_loss': 0.0412112,
#  'Loss/regularization_loss': 0.05414874,
#  'Loss/total_loss': 0.207061,
#  'learning_rate': 0.079740144}
# I1011 10:50:52.648723 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.11170105,
#  'Loss/localization_loss': 0.0412112,
#  'Loss/regularization_loss': 0.05414874,
#  'Loss/total_loss': 0.207061,
#  'learning_rate': 0.079740144}
# INFO:tensorflow:Step 13400 per-step time 0.539s
# I1011 10:51:46.535546 139567239794688 model_lib_v2.py:705] Step 13400 per-step time 0.539s
# INFO:tensorflow:{'Loss/classification_loss': 0.13878901,
#  'Loss/localization_loss': 0.06052387,
#  'Loss/regularization_loss': 0.054156434,
#  'Loss/total_loss': 0.25346932,
#  'learning_rate': 0.07973532}
# I1011 10:51:46.536112 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.13878901,
#  'Loss/localization_loss': 0.06052387,
#  'Loss/regularization_loss': 0.054156434,
#  'Loss/total_loss': 0.25346932,
#  'learning_rate': 0.07973532}
# INFO:tensorflow:Step 13500 per-step time 0.541s
# I1011 10:52:40.678444 139567239794688 model_lib_v2.py:705] Step 13500 per-step time 0.541s
# INFO:tensorflow:{'Loss/classification_loss': 0.11584349,
#  'Loss/localization_loss': 0.04898648,
#  'Loss/regularization_loss': 0.054214876,
#  'Loss/total_loss': 0.21904485,
#  'learning_rate': 0.07973044}
# I1011 10:52:40.678848 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.11584349,
#  'Loss/localization_loss': 0.04898648,
#  'Loss/regularization_loss': 0.054214876,
#  'Loss/total_loss': 0.21904485,
#  'learning_rate': 0.07973044}
# INFO:tensorflow:Step 13600 per-step time 0.539s
# I1011 10:53:34.586792 139567239794688 model_lib_v2.py:705] Step 13600 per-step time 0.539s
# INFO:tensorflow:{'Loss/classification_loss': 0.104040936,
#  'Loss/localization_loss': 0.032429382,
#  'Loss/regularization_loss': 0.054261528,
#  'Loss/total_loss': 0.19073184,
#  'learning_rate': 0.07972552}
# I1011 10:53:34.587154 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.104040936,
#  'Loss/localization_loss': 0.032429382,
#  'Loss/regularization_loss': 0.054261528,
#  'Loss/total_loss': 0.19073184,
#  'learning_rate': 0.07972552}
# INFO:tensorflow:Step 13700 per-step time 0.539s
# I1011 10:54:28.463551 139567239794688 model_lib_v2.py:705] Step 13700 per-step time 0.539s
# INFO:tensorflow:{'Loss/classification_loss': 0.14129616,
#  'Loss/localization_loss': 0.05863526,
#  'Loss/regularization_loss': 0.05429836,
#  'Loss/total_loss': 0.25422978,
#  'learning_rate': 0.079720564}
# I1011 10:54:28.463876 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.14129616,
#  'Loss/localization_loss': 0.05863526,
#  'Loss/regularization_loss': 0.05429836,
#  'Loss/total_loss': 0.25422978,
#  'learning_rate': 0.079720564}
# INFO:tensorflow:Step 13800 per-step time 0.544s
# I1011 10:55:22.852858 139567239794688 model_lib_v2.py:705] Step 13800 per-step time 0.544s
# INFO:tensorflow:{'Loss/classification_loss': 0.13541612,
#  'Loss/localization_loss': 0.04710093,
#  'Loss/regularization_loss': 0.05438658,
#  'Loss/total_loss': 0.23690364,
#  'learning_rate': 0.07971556}
# I1011 10:55:22.856372 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.13541612,
#  'Loss/localization_loss': 0.04710093,
#  'Loss/regularization_loss': 0.05438658,
#  'Loss/total_loss': 0.23690364,
#  'learning_rate': 0.07971556}
# INFO:tensorflow:Step 13900 per-step time 0.540s
# I1011 10:56:16.848025 139567239794688 model_lib_v2.py:705] Step 13900 per-step time 0.540s
# INFO:tensorflow:{'Loss/classification_loss': 0.124886565,
#  'Loss/localization_loss': 0.04700112,
#  'Loss/regularization_loss': 0.054434106,
#  'Loss/total_loss': 0.22632179,
#  'learning_rate': 0.0797105}
# I1011 10:56:16.848443 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.124886565,
#  'Loss/localization_loss': 0.04700112,
#  'Loss/regularization_loss': 0.054434106,
#  'Loss/total_loss': 0.22632179,
#  'learning_rate': 0.0797105}
# INFO:tensorflow:Step 14000 per-step time 0.541s
# I1011 10:57:10.948070 139567239794688 model_lib_v2.py:705] Step 14000 per-step time 0.541s
# INFO:tensorflow:{'Loss/classification_loss': 0.12447708,
#  'Loss/localization_loss': 0.043744314,
#  'Loss/regularization_loss': 0.054555424,
#  'Loss/total_loss': 0.22277682,
#  'learning_rate': 0.07970541}
# I1011 10:57:10.948459 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.12447708,
#  'Loss/localization_loss': 0.043744314,
#  'Loss/regularization_loss': 0.054555424,
#  'Loss/total_loss': 0.22277682,
#  'learning_rate': 0.07970541}
# INFO:tensorflow:Step 14100 per-step time 0.562s
# I1011 10:58:07.168637 139567239794688 model_lib_v2.py:705] Step 14100 per-step time 0.562s
# INFO:tensorflow:{'Loss/classification_loss': 0.1591551,
#  'Loss/localization_loss': 0.069472305,
#  'Loss/regularization_loss': 0.05476892,
#  'Loss/total_loss': 0.28339633,
#  'learning_rate': 0.07970027}
# I1011 10:58:07.168979 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.1591551,
#  'Loss/localization_loss': 0.069472305,
#  'Loss/regularization_loss': 0.05476892,
#  'Loss/total_loss': 0.28339633,
#  'learning_rate': 0.07970027}
# INFO:tensorflow:Step 14200 per-step time 0.540s
# I1011 10:59:01.154123 139567239794688 model_lib_v2.py:705] Step 14200 per-step time 0.540s
# INFO:tensorflow:{'Loss/classification_loss': 0.18322086,
#  'Loss/localization_loss': 0.08684581,
#  'Loss/regularization_loss': 0.054852657,
#  'Loss/total_loss': 0.32491934,
#  'learning_rate': 0.07969508}
# I1011 10:59:01.154571 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.18322086,
#  'Loss/localization_loss': 0.08684581,
#  'Loss/regularization_loss': 0.054852657,
#  'Loss/total_loss': 0.32491934,
#  'learning_rate': 0.07969508}
# INFO:tensorflow:Step 14300 per-step time 0.546s
# I1011 10:59:55.786633 139567239794688 model_lib_v2.py:705] Step 14300 per-step time 0.546s
# INFO:tensorflow:{'Loss/classification_loss': 0.14705774,
#  'Loss/localization_loss': 0.068158954,
#  'Loss/regularization_loss': 0.054904733,
#  'Loss/total_loss': 0.27012143,
#  'learning_rate': 0.07968986}
# I1011 10:59:55.787081 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.14705774,
#  'Loss/localization_loss': 0.068158954,
#  'Loss/regularization_loss': 0.054904733,
#  'Loss/total_loss': 0.27012143,
#  'learning_rate': 0.07968986}
# INFO:tensorflow:Step 14400 per-step time 0.546s
# I1011 11:00:50.407552 139567239794688 model_lib_v2.py:705] Step 14400 per-step time 0.546s
# INFO:tensorflow:{'Loss/classification_loss': 0.11849732,
#  'Loss/localization_loss': 0.045242444,
#  'Loss/regularization_loss': 0.054992124,
#  'Loss/total_loss': 0.2187319,
#  'learning_rate': 0.07968459}
# I1011 11:00:50.407903 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.11849732,
#  'Loss/localization_loss': 0.045242444,
#  'Loss/regularization_loss': 0.054992124,
#  'Loss/total_loss': 0.2187319,
#  'learning_rate': 0.07968459}
# INFO:tensorflow:Step 14500 per-step time 0.543s
# I1011 11:01:44.714906 139567239794688 model_lib_v2.py:705] Step 14500 per-step time 0.543s
# INFO:tensorflow:{'Loss/classification_loss': 0.16452327,
#  'Loss/localization_loss': 0.07375239,
#  'Loss/regularization_loss': 0.055030998,
#  'Loss/total_loss': 0.29330665,
#  'learning_rate': 0.079679266}
# I1011 11:01:44.715267 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.16452327,
#  'Loss/localization_loss': 0.07375239,
#  'Loss/regularization_loss': 0.055030998,
#  'Loss/total_loss': 0.29330665,
#  'learning_rate': 0.079679266}
# INFO:tensorflow:Step 14600 per-step time 0.547s
# I1011 11:02:39.400018 139567239794688 model_lib_v2.py:705] Step 14600 per-step time 0.547s
# INFO:tensorflow:{'Loss/classification_loss': 0.20064475,
#  'Loss/localization_loss': 0.05750522,
#  'Loss/regularization_loss': 0.05511498,
#  'Loss/total_loss': 0.31326494,
#  'learning_rate': 0.07967391}
# I1011 11:02:39.400444 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.20064475,
#  'Loss/localization_loss': 0.05750522,
#  'Loss/regularization_loss': 0.05511498,
#  'Loss/total_loss': 0.31326494,
#  'learning_rate': 0.07967391}
# INFO:tensorflow:Step 14700 per-step time 0.543s
# I1011 11:03:33.696044 139567239794688 model_lib_v2.py:705] Step 14700 per-step time 0.543s
# INFO:tensorflow:{'Loss/classification_loss': 0.15007284,
#  'Loss/localization_loss': 0.06283018,
#  'Loss/regularization_loss': 0.055169135,
#  'Loss/total_loss': 0.26807216,
#  'learning_rate': 0.07966851}
# I1011 11:03:33.696511 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.15007284,
#  'Loss/localization_loss': 0.06283018,
#  'Loss/regularization_loss': 0.055169135,
#  'Loss/total_loss': 0.26807216,
#  'learning_rate': 0.07966851}
# INFO:tensorflow:Step 14800 per-step time 0.545s
# I1011 11:04:28.130877 139567239794688 model_lib_v2.py:705] Step 14800 per-step time 0.545s
# INFO:tensorflow:{'Loss/classification_loss': 0.11914094,
#  'Loss/localization_loss': 0.05444348,
#  'Loss/regularization_loss': 0.055197243,
#  'Loss/total_loss': 0.22878166,
#  'learning_rate': 0.07966305}
# I1011 11:04:28.131177 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.11914094,
#  'Loss/localization_loss': 0.05444348,
#  'Loss/regularization_loss': 0.055197243,
#  'Loss/total_loss': 0.22878166,
#  'learning_rate': 0.07966305}
# INFO:tensorflow:Step 14900 per-step time 0.540s
# I1011 11:05:22.167487 139567239794688 model_lib_v2.py:705] Step 14900 per-step time 0.540s
# INFO:tensorflow:{'Loss/classification_loss': 0.12451925,
#  'Loss/localization_loss': 0.055552687,
#  'Loss/regularization_loss': 0.055237807,
#  'Loss/total_loss': 0.23530975,
#  'learning_rate': 0.07965756}
# I1011 11:05:22.167848 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.12451925,
#  'Loss/localization_loss': 0.055552687,
#  'Loss/regularization_loss': 0.055237807,
#  'Loss/total_loss': 0.23530975,
#  'learning_rate': 0.07965756}
# INFO:tensorflow:Step 15000 per-step time 0.538s
# I1011 11:06:15.970054 139567239794688 model_lib_v2.py:705] Step 15000 per-step time 0.538s
# INFO:tensorflow:{'Loss/classification_loss': 0.1712764,
#  'Loss/localization_loss': 0.08238651,
#  'Loss/regularization_loss': 0.055252023,
#  'Loss/total_loss': 0.30891496,
#  'learning_rate': 0.07965203}
# I1011 11:06:15.970485 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.1712764,
#  'Loss/localization_loss': 0.08238651,
#  'Loss/regularization_loss': 0.055252023,
#  'Loss/total_loss': 0.30891496,
#  'learning_rate': 0.07965203}
# INFO:tensorflow:Step 15100 per-step time 0.574s
# I1011 11:07:13.389600 139567239794688 model_lib_v2.py:705] Step 15100 per-step time 0.574s
# INFO:tensorflow:{'Loss/classification_loss': 0.13099602,
#  'Loss/localization_loss': 0.054746486,
#  'Loss/regularization_loss': 0.055313624,
#  'Loss/total_loss': 0.24105611,
#  'learning_rate': 0.079646446}
# I1011 11:07:13.389979 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.13099602,
#  'Loss/localization_loss': 0.054746486,
#  'Loss/regularization_loss': 0.055313624,
#  'Loss/total_loss': 0.24105611,
#  'learning_rate': 0.079646446}
# INFO:tensorflow:Step 15200 per-step time 0.539s
# I1011 11:08:07.322720 139567239794688 model_lib_v2.py:705] Step 15200 per-step time 0.539s
# INFO:tensorflow:{'Loss/classification_loss': 0.13215199,
#  'Loss/localization_loss': 0.06615953,
#  'Loss/regularization_loss': 0.055394307,
#  'Loss/total_loss': 0.25370583,
#  'learning_rate': 0.07964081}
# I1011 11:08:07.323030 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.13215199,
#  'Loss/localization_loss': 0.06615953,
#  'Loss/regularization_loss': 0.055394307,
#  'Loss/total_loss': 0.25370583,
#  'learning_rate': 0.07964081}
# INFO:tensorflow:Step 15300 per-step time 0.539s
# I1011 11:09:01.186573 139567239794688 model_lib_v2.py:705] Step 15300 per-step time 0.539s
# INFO:tensorflow:{'Loss/classification_loss': 0.11428621,
#  'Loss/localization_loss': 0.04070553,
#  'Loss/regularization_loss': 0.05542416,
#  'Loss/total_loss': 0.2104159,
#  'learning_rate': 0.07963515}
# I1011 11:09:01.186975 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.11428621,
#  'Loss/localization_loss': 0.04070553,
#  'Loss/regularization_loss': 0.05542416,
#  'Loss/total_loss': 0.2104159,
#  'learning_rate': 0.07963515}
# INFO:tensorflow:Step 15400 per-step time 0.541s
# I1011 11:09:55.296906 139567239794688 model_lib_v2.py:705] Step 15400 per-step time 0.541s
# INFO:tensorflow:{'Loss/classification_loss': 0.18225816,
#  'Loss/localization_loss': 0.07323492,
#  'Loss/regularization_loss': 0.05548651,
#  'Loss/total_loss': 0.3109796,
#  'learning_rate': 0.079629436}
# I1011 11:09:55.297310 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.18225816,
#  'Loss/localization_loss': 0.07323492,
#  'Loss/regularization_loss': 0.05548651,
#  'Loss/total_loss': 0.3109796,
#  'learning_rate': 0.079629436}
# INFO:tensorflow:Step 15500 per-step time 0.541s
# I1011 11:10:49.365965 139567239794688 model_lib_v2.py:705] Step 15500 per-step time 0.541s
# INFO:tensorflow:{'Loss/classification_loss': 0.11302149,
#  'Loss/localization_loss': 0.05519202,
#  'Loss/regularization_loss': 0.0554925,
#  'Loss/total_loss': 0.22370602,
#  'learning_rate': 0.07962368}
# I1011 11:10:49.366401 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.11302149,
#  'Loss/localization_loss': 0.05519202,
#  'Loss/regularization_loss': 0.0554925,
#  'Loss/total_loss': 0.22370602,
#  'learning_rate': 0.07962368}
# INFO:tensorflow:Step 15600 per-step time 0.541s
# I1011 11:11:43.468705 139567239794688 model_lib_v2.py:705] Step 15600 per-step time 0.541s
# INFO:tensorflow:{'Loss/classification_loss': 0.15062082,
#  'Loss/localization_loss': 0.07912643,
#  'Loss/regularization_loss': 0.055538666,
#  'Loss/total_loss': 0.28528592,
#  'learning_rate': 0.07961787}
# I1011 11:11:43.469055 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.15062082,
#  'Loss/localization_loss': 0.07912643,
#  'Loss/regularization_loss': 0.055538666,
#  'Loss/total_loss': 0.28528592,
#  'learning_rate': 0.07961787}
# INFO:tensorflow:Step 15700 per-step time 0.541s
# I1011 11:12:37.565907 139567239794688 model_lib_v2.py:705] Step 15700 per-step time 0.541s
# INFO:tensorflow:{'Loss/classification_loss': 0.1386406,
#  'Loss/localization_loss': 0.043449286,
#  'Loss/regularization_loss': 0.055648096,
#  'Loss/total_loss': 0.23773798,
#  'learning_rate': 0.079612024}
# I1011 11:12:37.566298 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.1386406,
#  'Loss/localization_loss': 0.043449286,
#  'Loss/regularization_loss': 0.055648096,
#  'Loss/total_loss': 0.23773798,
#  'learning_rate': 0.079612024}
# INFO:tensorflow:Step 15800 per-step time 0.542s
# I1011 11:13:31.790404 139567239794688 model_lib_v2.py:705] Step 15800 per-step time 0.542s
# INFO:tensorflow:{'Loss/classification_loss': 0.150193,
#  'Loss/localization_loss': 0.04468839,
#  'Loss/regularization_loss': 0.055740595,
#  'Loss/total_loss': 0.25062197,
#  'learning_rate': 0.07960614}
# I1011 11:13:31.790857 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.150193,
#  'Loss/localization_loss': 0.04468839,
#  'Loss/regularization_loss': 0.055740595,
#  'Loss/total_loss': 0.25062197,
#  'learning_rate': 0.07960614}
# INFO:tensorflow:Step 15900 per-step time 0.542s
# I1011 11:14:26.023366 139567239794688 model_lib_v2.py:705] Step 15900 per-step time 0.542s
# INFO:tensorflow:{'Loss/classification_loss': 0.098321155,
#  'Loss/localization_loss': 0.038700152,
#  'Loss/regularization_loss': 0.055769026,
#  'Loss/total_loss': 0.19279033,
#  'learning_rate': 0.0796002}
# I1011 11:14:26.023694 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.098321155,
#  'Loss/localization_loss': 0.038700152,
#  'Loss/regularization_loss': 0.055769026,
#  'Loss/total_loss': 0.19279033,
#  'learning_rate': 0.0796002}
# INFO:tensorflow:Step 16000 per-step time 0.537s
# I1011 11:15:19.739661 139567239794688 model_lib_v2.py:705] Step 16000 per-step time 0.537s
# INFO:tensorflow:{'Loss/classification_loss': 0.13209806,
#  'Loss/localization_loss': 0.04404364,
#  'Loss/regularization_loss': 0.05578426,
#  'Loss/total_loss': 0.23192596,
#  'learning_rate': 0.07959422}
# I1011 11:15:19.740015 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.13209806,
#  'Loss/localization_loss': 0.04404364,
#  'Loss/regularization_loss': 0.05578426,
#  'Loss/total_loss': 0.23192596,
#  'learning_rate': 0.07959422}
# INFO:tensorflow:Step 16100 per-step time 0.563s
# I1011 11:16:16.061706 139567239794688 model_lib_v2.py:705] Step 16100 per-step time 0.563s
# INFO:tensorflow:{'Loss/classification_loss': 0.143208,
#  'Loss/localization_loss': 0.05802282,
#  'Loss/regularization_loss': 0.05578737,
#  'Loss/total_loss': 0.25701818,
#  'learning_rate': 0.0795882}
# I1011 11:16:16.064691 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.143208,
#  'Loss/localization_loss': 0.05802282,
#  'Loss/regularization_loss': 0.05578737,
#  'Loss/total_loss': 0.25701818,
#  'learning_rate': 0.0795882}
# INFO:tensorflow:Step 16200 per-step time 0.543s
# I1011 11:17:10.354182 139567239794688 model_lib_v2.py:705] Step 16200 per-step time 0.543s
# INFO:tensorflow:{'Loss/classification_loss': 0.13084514,
#  'Loss/localization_loss': 0.06900177,
#  'Loss/regularization_loss': 0.05581161,
#  'Loss/total_loss': 0.25565854,
#  'learning_rate': 0.079582125}
# I1011 11:17:10.354621 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.13084514,
#  'Loss/localization_loss': 0.06900177,
#  'Loss/regularization_loss': 0.05581161,
#  'Loss/total_loss': 0.25565854,
#  'learning_rate': 0.079582125}
# INFO:tensorflow:Step 16300 per-step time 0.541s
# I1011 11:18:04.458054 139567239794688 model_lib_v2.py:705] Step 16300 per-step time 0.541s
# INFO:tensorflow:{'Loss/classification_loss': 0.17399745,
#  'Loss/localization_loss': 0.065912955,
#  'Loss/regularization_loss': 0.055850107,
#  'Loss/total_loss': 0.2957605,
#  'learning_rate': 0.079576015}
# I1011 11:18:04.458401 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.17399745,
#  'Loss/localization_loss': 0.065912955,
#  'Loss/regularization_loss': 0.055850107,
#  'Loss/total_loss': 0.2957605,
#  'learning_rate': 0.079576015}
# INFO:tensorflow:Step 16400 per-step time 0.538s
# I1011 11:18:58.266192 139567239794688 model_lib_v2.py:705] Step 16400 per-step time 0.538s
# INFO:tensorflow:{'Loss/classification_loss': 0.2712591,
#  'Loss/localization_loss': 0.09464408,
#  'Loss/regularization_loss': 0.055889588,
#  'Loss/total_loss': 0.42179275,
#  'learning_rate': 0.07956986}
# I1011 11:18:58.266555 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.2712591,
#  'Loss/localization_loss': 0.09464408,
#  'Loss/regularization_loss': 0.055889588,
#  'Loss/total_loss': 0.42179275,
#  'learning_rate': 0.07956986}
# INFO:tensorflow:Step 16500 per-step time 0.540s
# I1011 11:19:52.241849 139567239794688 model_lib_v2.py:705] Step 16500 per-step time 0.540s
# INFO:tensorflow:{'Loss/classification_loss': 0.10857881,
#  'Loss/localization_loss': 0.036613923,
#  'Loss/regularization_loss': 0.056006074,
#  'Loss/total_loss': 0.2011988,
#  'learning_rate': 0.07956366}
# I1011 11:19:52.242271 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.10857881,
#  'Loss/localization_loss': 0.036613923,
#  'Loss/regularization_loss': 0.056006074,
#  'Loss/total_loss': 0.2011988,
#  'learning_rate': 0.07956366}
# INFO:tensorflow:Step 16600 per-step time 0.546s
# I1011 11:20:46.852880 139567239794688 model_lib_v2.py:705] Step 16600 per-step time 0.546s
# INFO:tensorflow:{'Loss/classification_loss': 0.1551521,
#  'Loss/localization_loss': 0.048513763,
#  'Loss/regularization_loss': 0.05601915,
#  'Loss/total_loss': 0.259685,
#  'learning_rate': 0.07955742}
# I1011 11:20:46.853287 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.1551521,
#  'Loss/localization_loss': 0.048513763,
#  'Loss/regularization_loss': 0.05601915,
#  'Loss/total_loss': 0.259685,
#  'learning_rate': 0.07955742}
# INFO:tensorflow:Step 16700 per-step time 0.542s
# I1011 11:21:41.035657 139567239794688 model_lib_v2.py:705] Step 16700 per-step time 0.542s
# INFO:tensorflow:{'Loss/classification_loss': 0.12776653,
#  'Loss/localization_loss': 0.04825952,
#  'Loss/regularization_loss': 0.056063943,
#  'Loss/total_loss': 0.23209,
#  'learning_rate': 0.07955113}
# I1011 11:21:41.036000 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.12776653,
#  'Loss/localization_loss': 0.04825952,
#  'Loss/regularization_loss': 0.056063943,
#  'Loss/total_loss': 0.23209,
#  'learning_rate': 0.07955113}
# INFO:tensorflow:Step 16800 per-step time 0.539s
# I1011 11:22:34.979570 139567239794688 model_lib_v2.py:705] Step 16800 per-step time 0.539s
# INFO:tensorflow:{'Loss/classification_loss': 0.13545854,
#  'Loss/localization_loss': 0.06553179,
#  'Loss/regularization_loss': 0.05626431,
#  'Loss/total_loss': 0.25725466,
#  'learning_rate': 0.0795448}
# I1011 11:22:34.979898 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.13545854,
#  'Loss/localization_loss': 0.06553179,
#  'Loss/regularization_loss': 0.05626431,
#  'Loss/total_loss': 0.25725466,
#  'learning_rate': 0.0795448}
# INFO:tensorflow:Step 16900 per-step time 0.541s
# I1011 11:23:29.081395 139567239794688 model_lib_v2.py:705] Step 16900 per-step time 0.541s
# INFO:tensorflow:{'Loss/classification_loss': 0.12137212,
#  'Loss/localization_loss': 0.052261688,
#  'Loss/regularization_loss': 0.056507483,
#  'Loss/total_loss': 0.23014128,
#  'learning_rate': 0.07953842}
# I1011 11:23:29.081835 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.12137212,
#  'Loss/localization_loss': 0.052261688,
#  'Loss/regularization_loss': 0.056507483,
#  'Loss/total_loss': 0.23014128,
#  'learning_rate': 0.07953842}
# INFO:tensorflow:Step 17000 per-step time 0.541s
# I1011 11:24:23.202090 139567239794688 model_lib_v2.py:705] Step 17000 per-step time 0.541s
# INFO:tensorflow:{'Loss/classification_loss': 0.13539228,
#  'Loss/localization_loss': 0.050942548,
#  'Loss/regularization_loss': 0.056547552,
#  'Loss/total_loss': 0.24288237,
#  'learning_rate': 0.079532005}
# I1011 11:24:23.202492 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.13539228,
#  'Loss/localization_loss': 0.050942548,
#  'Loss/regularization_loss': 0.056547552,
#  'Loss/total_loss': 0.24288237,
#  'learning_rate': 0.079532005}
# INFO:tensorflow:Step 17100 per-step time 0.585s
# I1011 11:25:21.648151 139567239794688 model_lib_v2.py:705] Step 17100 per-step time 0.585s
# INFO:tensorflow:{'Loss/classification_loss': 0.14496124,
#  'Loss/localization_loss': 0.075526394,
#  'Loss/regularization_loss': 0.05653778,
#  'Loss/total_loss': 0.2770254,
#  'learning_rate': 0.07952554}
# I1011 11:25:21.648531 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.14496124,
#  'Loss/localization_loss': 0.075526394,
#  'Loss/regularization_loss': 0.05653778,
#  'Loss/total_loss': 0.2770254,
#  'learning_rate': 0.07952554}
# INFO:tensorflow:Step 17200 per-step time 0.539s
# I1011 11:26:15.537226 139567239794688 model_lib_v2.py:705] Step 17200 per-step time 0.539s
# INFO:tensorflow:{'Loss/classification_loss': 0.16313456,
#  'Loss/localization_loss': 0.122422,
#  'Loss/regularization_loss': 0.05657224,
#  'Loss/total_loss': 0.3421288,
#  'learning_rate': 0.079519026}
# I1011 11:26:15.537617 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.16313456,
#  'Loss/localization_loss': 0.122422,
#  'Loss/regularization_loss': 0.05657224,
#  'Loss/total_loss': 0.3421288,
#  'learning_rate': 0.079519026}
# INFO:tensorflow:Step 17300 per-step time 0.540s
# I1011 11:27:09.578546 139567239794688 model_lib_v2.py:705] Step 17300 per-step time 0.540s
# INFO:tensorflow:{'Loss/classification_loss': 0.14711297,
#  'Loss/localization_loss': 0.060841583,
#  'Loss/regularization_loss': 0.05662696,
#  'Loss/total_loss': 0.2645815,
#  'learning_rate': 0.07951248}
# I1011 11:27:09.578979 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.14711297,
#  'Loss/localization_loss': 0.060841583,
#  'Loss/regularization_loss': 0.05662696,
#  'Loss/total_loss': 0.2645815,
#  'learning_rate': 0.07951248}
# INFO:tensorflow:Step 17400 per-step time 0.542s
# I1011 11:28:03.765469 139567239794688 model_lib_v2.py:705] Step 17400 per-step time 0.542s
# INFO:tensorflow:{'Loss/classification_loss': 0.17203401,
#  'Loss/localization_loss': 0.054802828,
#  'Loss/regularization_loss': 0.05664969,
#  'Loss/total_loss': 0.28348652,
#  'learning_rate': 0.07950588}
# I1011 11:28:03.765866 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.17203401,
#  'Loss/localization_loss': 0.054802828,
#  'Loss/regularization_loss': 0.05664969,
#  'Loss/total_loss': 0.28348652,
#  'learning_rate': 0.07950588}
# INFO:tensorflow:Step 17500 per-step time 0.545s
# I1011 11:28:58.257341 139567239794688 model_lib_v2.py:705] Step 17500 per-step time 0.545s
# INFO:tensorflow:{'Loss/classification_loss': 0.09997243,
#  'Loss/localization_loss': 0.022415448,
#  'Loss/regularization_loss': 0.056783214,
#  'Loss/total_loss': 0.17917109,
#  'learning_rate': 0.07949924}
# I1011 11:28:58.257697 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.09997243,
#  'Loss/localization_loss': 0.022415448,
#  'Loss/regularization_loss': 0.056783214,
#  'Loss/total_loss': 0.17917109,
#  'learning_rate': 0.07949924}
# INFO:tensorflow:Step 17600 per-step time 0.541s
# I1011 11:29:52.326685 139567239794688 model_lib_v2.py:705] Step 17600 per-step time 0.541s
# INFO:tensorflow:{'Loss/classification_loss': 0.12127655,
#  'Loss/localization_loss': 0.0447958,
#  'Loss/regularization_loss': 0.056818243,
#  'Loss/total_loss': 0.22289059,
#  'learning_rate': 0.079492554}
# I1011 11:29:52.327086 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.12127655,
#  'Loss/localization_loss': 0.0447958,
#  'Loss/regularization_loss': 0.056818243,
#  'Loss/total_loss': 0.22289059,
#  'learning_rate': 0.079492554}
# INFO:tensorflow:Step 17700 per-step time 0.541s
# I1011 11:30:46.451504 139567239794688 model_lib_v2.py:705] Step 17700 per-step time 0.541s
# INFO:tensorflow:{'Loss/classification_loss': 0.10489161,
#  'Loss/localization_loss': 0.037082776,
#  'Loss/regularization_loss': 0.056891598,
#  'Loss/total_loss': 0.198866,
#  'learning_rate': 0.079485826}
# I1011 11:30:46.451917 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.10489161,
#  'Loss/localization_loss': 0.037082776,
#  'Loss/regularization_loss': 0.056891598,
#  'Loss/total_loss': 0.198866,
#  'learning_rate': 0.079485826}
# INFO:tensorflow:Step 17800 per-step time 0.542s
# I1011 11:31:40.623167 139567239794688 model_lib_v2.py:705] Step 17800 per-step time 0.542s
# INFO:tensorflow:{'Loss/classification_loss': 0.17722473,
#  'Loss/localization_loss': 0.066919215,
#  'Loss/regularization_loss': 0.05689568,
#  'Loss/total_loss': 0.3010396,
#  'learning_rate': 0.07947905}
# I1011 11:31:40.624584 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.17722473,
#  'Loss/localization_loss': 0.066919215,
#  'Loss/regularization_loss': 0.05689568,
#  'Loss/total_loss': 0.3010396,
#  'learning_rate': 0.07947905}
# INFO:tensorflow:Step 17900 per-step time 0.540s
# I1011 11:32:34.575641 139567239794688 model_lib_v2.py:705] Step 17900 per-step time 0.540s
# INFO:tensorflow:{'Loss/classification_loss': 0.13657477,
#  'Loss/localization_loss': 0.056911416,
#  'Loss/regularization_loss': 0.056923635,
#  'Loss/total_loss': 0.2504098,
#  'learning_rate': 0.07947224}
# I1011 11:32:34.575958 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.13657477,
#  'Loss/localization_loss': 0.056911416,
#  'Loss/regularization_loss': 0.056923635,
#  'Loss/total_loss': 0.2504098,
#  'learning_rate': 0.07947224}
# INFO:tensorflow:Step 18000 per-step time 0.545s
# I1011 11:33:29.112492 139567239794688 model_lib_v2.py:705] Step 18000 per-step time 0.545s
# INFO:tensorflow:{'Loss/classification_loss': 0.14934859,
#  'Loss/localization_loss': 0.043248102,
#  'Loss/regularization_loss': 0.056936804,
#  'Loss/total_loss': 0.24953349,
#  'learning_rate': 0.079465374}
# I1011 11:33:29.112919 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.14934859,
#  'Loss/localization_loss': 0.043248102,
#  'Loss/regularization_loss': 0.056936804,
#  'Loss/total_loss': 0.24953349,
#  'learning_rate': 0.079465374}
# INFO:tensorflow:Step 18100 per-step time 0.574s
# I1011 11:34:26.515057 139567239794688 model_lib_v2.py:705] Step 18100 per-step time 0.574s
# INFO:tensorflow:{'Loss/classification_loss': 0.16494161,
#  'Loss/localization_loss': 0.063691214,
#  'Loss/regularization_loss': 0.056938477,
#  'Loss/total_loss': 0.28557128,
#  'learning_rate': 0.07945847}
# I1011 11:34:26.515493 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.16494161,
#  'Loss/localization_loss': 0.063691214,
#  'Loss/regularization_loss': 0.056938477,
#  'Loss/total_loss': 0.28557128,
#  'learning_rate': 0.07945847}
# INFO:tensorflow:Step 18200 per-step time 0.541s
# I1011 11:35:20.583840 139567239794688 model_lib_v2.py:705] Step 18200 per-step time 0.541s
# INFO:tensorflow:{'Loss/classification_loss': 0.14911874,
#  'Loss/localization_loss': 0.0639411,
#  'Loss/regularization_loss': 0.056963354,
#  'Loss/total_loss': 0.2700232,
#  'learning_rate': 0.07945152}
# I1011 11:35:20.584196 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.14911874,
#  'Loss/localization_loss': 0.0639411,
#  'Loss/regularization_loss': 0.056963354,
#  'Loss/total_loss': 0.2700232,
#  'learning_rate': 0.07945152}
# INFO:tensorflow:Step 18300 per-step time 0.540s
# I1011 11:36:14.582833 139567239794688 model_lib_v2.py:705] Step 18300 per-step time 0.540s
# INFO:tensorflow:{'Loss/classification_loss': 0.11062115,
#  'Loss/localization_loss': 0.040610887,
#  'Loss/regularization_loss': 0.05697983,
#  'Loss/total_loss': 0.20821187,
#  'learning_rate': 0.07944453}
# I1011 11:36:14.583207 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.11062115,
#  'Loss/localization_loss': 0.040610887,
#  'Loss/regularization_loss': 0.05697983,
#  'Loss/total_loss': 0.20821187,
#  'learning_rate': 0.07944453}
# INFO:tensorflow:Step 18400 per-step time 0.544s
# I1011 11:37:08.978238 139567239794688 model_lib_v2.py:705] Step 18400 per-step time 0.544s
# INFO:tensorflow:{'Loss/classification_loss': 0.19487725,
#  'Loss/localization_loss': 0.09668637,
#  'Loss/regularization_loss': 0.05698871,
#  'Loss/total_loss': 0.34855232,
#  'learning_rate': 0.079437494}
# I1011 11:37:08.978676 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.19487725,
#  'Loss/localization_loss': 0.09668637,
#  'Loss/regularization_loss': 0.05698871,
#  'Loss/total_loss': 0.34855232,
#  'learning_rate': 0.079437494}
# INFO:tensorflow:Step 18500 per-step time 0.543s
# ...
# I1011 12:12:37.476276 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.10357374,
#  'Loss/localization_loss': 0.039787743,
#  'Loss/regularization_loss': 0.058798492,
#  'Loss/total_loss': 0.20215997,
#  'learning_rate': 0.079128824}
# INFO:tensorflow:Step 22400 per-step time 0.543s
# I1011 12:13:31.791674 139567239794688 model_lib_v2.py:705] Step 22400 per-step time 0.543s
# INFO:tensorflow:{'Loss/classification_loss': 0.23326188,
#  'Loss/localization_loss': 0.085392356,
#  'Loss/regularization_loss': 0.058809824,
#  'Loss/total_loss': 0.37746406,
#  'learning_rate': 0.07912004}
# I1011 12:13:31.792108 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.23326188,
#  'Loss/localization_loss': 0.085392356,
#  'Loss/regularization_loss': 0.058809824,
#  'Loss/total_loss': 0.37746406,
#  'learning_rate': 0.07912004}
# INFO:tensorflow:Step 22500 per-step time 0.544s
# I1011 12:14:26.229079 139567239794688 model_lib_v2.py:705] Step 22500 per-step time 0.544s
# INFO:tensorflow:{'Loss/classification_loss': 0.12056339,
#  'Loss/localization_loss': 0.045495506,
#  'Loss/regularization_loss': 0.058798105,
#  'Loss/total_loss': 0.224857,
#  'learning_rate': 0.0791112}
# I1011 12:14:26.229425 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.12056339,
#  'Loss/localization_loss': 0.045495506,
#  'Loss/regularization_loss': 0.058798105,
#  'Loss/total_loss': 0.224857,
#  'learning_rate': 0.0791112}
# INFO:tensorflow:Step 22600 per-step time 0.540s
# I1011 12:15:20.247354 139567239794688 model_lib_v2.py:705] Step 22600 per-step time 0.540s
# INFO:tensorflow:{'Loss/classification_loss': 0.14721306,
#  'Loss/localization_loss': 0.070143834,
#  'Loss/regularization_loss': 0.0587941,
#  'Loss/total_loss': 0.276151,
#  'learning_rate': 0.07910233}
# I1011 12:15:20.247895 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.14721306,
#  'Loss/localization_loss': 0.070143834,
#  'Loss/regularization_loss': 0.0587941,
#  'Loss/total_loss': 0.276151,
#  'learning_rate': 0.07910233}
# INFO:tensorflow:Step 22700 per-step time 0.545s
# I1011 12:16:14.758941 139567239794688 model_lib_v2.py:705] Step 22700 per-step time 0.545s
# INFO:tensorflow:{'Loss/classification_loss': 0.10237356,
#  'Loss/localization_loss': 0.03728221,
#  'Loss/regularization_loss': 0.05880093,
#  'Loss/total_loss': 0.1984567,
#  'learning_rate': 0.079093404}
# I1011 12:16:14.759365 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.10237356,
#  'Loss/localization_loss': 0.03728221,
#  'Loss/regularization_loss': 0.05880093,
#  'Loss/total_loss': 0.1984567,
#  'learning_rate': 0.079093404}
# INFO:tensorflow:Step 22800 per-step time 0.544s
# I1011 12:17:09.145413 139567239794688 model_lib_v2.py:705] Step 22800 per-step time 0.544s
# INFO:tensorflow:{'Loss/classification_loss': 0.10838456,
#  'Loss/localization_loss': 0.039340213,
#  'Loss/regularization_loss': 0.058775257,
#  'Loss/total_loss': 0.20650002,
#  'learning_rate': 0.07908444}
# I1011 12:17:09.145766 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.10838456,
#  'Loss/localization_loss': 0.039340213,
#  'Loss/regularization_loss': 0.058775257,
#  'Loss/total_loss': 0.20650002,
#  'learning_rate': 0.07908444}
# INFO:tensorflow:Step 22900 per-step time 0.546s
# I1011 12:18:03.773724 139567239794688 model_lib_v2.py:705] Step 22900 per-step time 0.546s
# INFO:tensorflow:{'Loss/classification_loss': 0.10684721,
#  'Loss/localization_loss': 0.040044982,
#  'Loss/regularization_loss': 0.058807548,
#  'Loss/total_loss': 0.20569974,
#  'learning_rate': 0.07907544}
# I1011 12:18:03.774046 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.10684721,
#  'Loss/localization_loss': 0.040044982,
#  'Loss/regularization_loss': 0.058807548,
#  'Loss/total_loss': 0.20569974,
#  'learning_rate': 0.07907544}
# INFO:tensorflow:Step 23000 per-step time 0.539s
# I1011 12:18:57.670939 139567239794688 model_lib_v2.py:705] Step 23000 per-step time 0.539s
# INFO:tensorflow:{'Loss/classification_loss': 0.086579755,
#  'Loss/localization_loss': 0.031813186,
#  'Loss/regularization_loss': 0.058822315,
#  'Loss/total_loss': 0.17721526,
#  'learning_rate': 0.07906638}
# I1011 12:18:57.671389 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.086579755,
#  'Loss/localization_loss': 0.031813186,
#  'Loss/regularization_loss': 0.058822315,
#  'Loss/total_loss': 0.17721526,
#  'learning_rate': 0.07906638}
# INFO:tensorflow:Step 23100 per-step time 0.576s
# I1011 12:19:55.284437 139567239794688 model_lib_v2.py:705] Step 23100 per-step time 0.576s
# INFO:tensorflow:{'Loss/classification_loss': 0.10584958,
#  'Loss/localization_loss': 0.03469872,
#  'Loss/regularization_loss': 0.058835804,
#  'Loss/total_loss': 0.19938411,
#  'learning_rate': 0.07905729}
# I1011 12:19:55.284811 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.10584958,
#  'Loss/localization_loss': 0.03469872,
#  'Loss/regularization_loss': 0.058835804,
#  'Loss/total_loss': 0.19938411,
#  'learning_rate': 0.07905729}
# INFO:tensorflow:Step 23200 per-step time 0.539s
# I1011 12:20:49.192032 139567239794688 model_lib_v2.py:705] Step 23200 per-step time 0.539s
# INFO:tensorflow:{'Loss/classification_loss': 0.10613808,
#  'Loss/localization_loss': 0.03130957,
#  'Loss/regularization_loss': 0.05884067,
#  'Loss/total_loss': 0.19628832,
#  'learning_rate': 0.07904816}
# I1011 12:20:49.192386 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.10613808,
#  'Loss/localization_loss': 0.03130957,
#  'Loss/regularization_loss': 0.05884067,
#  'Loss/total_loss': 0.19628832,
#  'learning_rate': 0.07904816}
# INFO:tensorflow:Step 23300 per-step time 0.541s
# I1011 12:21:43.309881 139567239794688 model_lib_v2.py:705] Step 23300 per-step time 0.541s
# INFO:tensorflow:{'Loss/classification_loss': 0.112271875,
#  'Loss/localization_loss': 0.03266541,
#  'Loss/regularization_loss': 0.05884909,
#  'Loss/total_loss': 0.20378637,
#  'learning_rate': 0.07903897}
# I1011 12:21:43.310287 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.112271875,
#  'Loss/localization_loss': 0.03266541,
#  'Loss/regularization_loss': 0.05884909,
#  'Loss/total_loss': 0.20378637,
#  'learning_rate': 0.07903897}
# INFO:tensorflow:Step 23400 per-step time 0.547s
# I1011 12:22:37.997207 139567239794688 model_lib_v2.py:705] Step 23400 per-step time 0.547s
# INFO:tensorflow:{'Loss/classification_loss': 0.091076076,
#  'Loss/localization_loss': 0.035595294,
#  'Loss/regularization_loss': 0.058877885,
#  'Loss/total_loss': 0.18554926,
#  'learning_rate': 0.07902975}
# I1011 12:22:37.997746 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.091076076,
#  'Loss/localization_loss': 0.035595294,
#  'Loss/regularization_loss': 0.058877885,
#  'Loss/total_loss': 0.18554926,
#  'learning_rate': 0.07902975}
# INFO:tensorflow:Step 23500 per-step time 0.543s
# I1011 12:23:32.288731 139567239794688 model_lib_v2.py:705] Step 23500 per-step time 0.543s
# INFO:tensorflow:{'Loss/classification_loss': 0.13530597,
#  'Loss/localization_loss': 0.058556356,
#  'Loss/regularization_loss': 0.058910783,
#  'Loss/total_loss': 0.2527731,
#  'learning_rate': 0.07902048}
# I1011 12:23:32.289183 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.13530597,
#  'Loss/localization_loss': 0.058556356,
#  'Loss/regularization_loss': 0.058910783,
#  'Loss/total_loss': 0.2527731,
#  'learning_rate': 0.07902048}
# INFO:tensorflow:Step 23600 per-step time 0.540s
# I1011 12:24:26.252237 139567239794688 model_lib_v2.py:705] Step 23600 per-step time 0.540s
# INFO:tensorflow:{'Loss/classification_loss': 0.101660095,
#  'Loss/localization_loss': 0.034100853,
#  'Loss/regularization_loss': 0.058916297,
#  'Loss/total_loss': 0.19467723,
#  'learning_rate': 0.079011165}
# I1011 12:24:26.252547 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.101660095,
#  'Loss/localization_loss': 0.034100853,
#  'Loss/regularization_loss': 0.058916297,
#  'Loss/total_loss': 0.19467723,
#  'learning_rate': 0.079011165}
# INFO:tensorflow:Step 23700 per-step time 0.541s
# I1011 12:25:20.350512 139567239794688 model_lib_v2.py:705] Step 23700 per-step time 0.541s
# INFO:tensorflow:{'Loss/classification_loss': 0.08741797,
#  'Loss/localization_loss': 0.023188526,
#  'Loss/regularization_loss': 0.058901798,
#  'Loss/total_loss': 0.1695083,
#  'learning_rate': 0.07900181}
# I1011 12:25:20.350966 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.08741797,
#  'Loss/localization_loss': 0.023188526,
#  'Loss/regularization_loss': 0.058901798,
#  'Loss/total_loss': 0.1695083,
#  'learning_rate': 0.07900181}
# INFO:tensorflow:Step 23800 per-step time 0.538s
# I1011 12:26:14.158262 139567239794688 model_lib_v2.py:705] Step 23800 per-step time 0.538s
# INFO:tensorflow:{'Loss/classification_loss': 0.114386484,
#  'Loss/localization_loss': 0.060347386,
#  'Loss/regularization_loss': 0.058896866,
#  'Loss/total_loss': 0.23363075,
#  'learning_rate': 0.07899241}
# I1011 12:26:14.158691 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.114386484,
#  'Loss/localization_loss': 0.060347386,
#  'Loss/regularization_loss': 0.058896866,
#  'Loss/total_loss': 0.23363075,
#  'learning_rate': 0.07899241}
# INFO:tensorflow:Step 23900 per-step time 0.545s
# I1011 12:27:08.645437 139567239794688 model_lib_v2.py:705] Step 23900 per-step time 0.545s
# INFO:tensorflow:{'Loss/classification_loss': 0.109912954,
#  'Loss/localization_loss': 0.02757567,
#  'Loss/regularization_loss': 0.058924753,
#  'Loss/total_loss': 0.19641338,
#  'learning_rate': 0.078982964}
# I1011 12:27:08.645873 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.109912954,
#  'Loss/localization_loss': 0.02757567,
#  'Loss/regularization_loss': 0.058924753,
#  'Loss/total_loss': 0.19641338,
#  'learning_rate': 0.078982964}
# INFO:tensorflow:Step 24000 per-step time 0.541s
# I1011 12:28:02.691365 139567239794688 model_lib_v2.py:705] Step 24000 per-step time 0.541s
# INFO:tensorflow:{'Loss/classification_loss': 0.104842916,
#  'Loss/localization_loss': 0.039981753,
#  'Loss/regularization_loss': 0.058910064,
#  'Loss/total_loss': 0.20373473,
#  'learning_rate': 0.07897348}
# I1011 12:28:02.691696 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.104842916,
#  'Loss/localization_loss': 0.039981753,
#  'Loss/regularization_loss': 0.058910064,
#  'Loss/total_loss': 0.20373473,
#  'learning_rate': 0.07897348}
# INFO:tensorflow:Step 24100 per-step time 0.564s
# I1011 12:28:59.052740 139567239794688 model_lib_v2.py:705] Step 24100 per-step time 0.564s
# INFO:tensorflow:{'Loss/classification_loss': 0.11854984,
#  'Loss/localization_loss': 0.030816605,
#  'Loss/regularization_loss': 0.058890253,
#  'Loss/total_loss': 0.20825669,
#  'learning_rate': 0.07896395}
# I1011 12:28:59.053176 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.11854984,
#  'Loss/localization_loss': 0.030816605,
#  'Loss/regularization_loss': 0.058890253,
#  'Loss/total_loss': 0.20825669,
#  'learning_rate': 0.07896395}
# INFO:tensorflow:Step 24200 per-step time 0.541s
# I1011 12:29:53.178962 139567239794688 model_lib_v2.py:705] Step 24200 per-step time 0.541s
# INFO:tensorflow:{'Loss/classification_loss': 0.097755134,
#  'Loss/localization_loss': 0.03340582,
#  'Loss/regularization_loss': 0.05892456,
#  'Loss/total_loss': 0.19008552,
#  'learning_rate': 0.078954384}
# I1011 12:29:53.179412 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.097755134,
#  'Loss/localization_loss': 0.03340582,
#  'Loss/regularization_loss': 0.05892456,
#  'Loss/total_loss': 0.19008552,
#  'learning_rate': 0.078954384}
# INFO:tensorflow:Step 24300 per-step time 0.544s
# I1011 12:30:47.604727 139567239794688 model_lib_v2.py:705] Step 24300 per-step time 0.544s
# INFO:tensorflow:{'Loss/classification_loss': 0.09228434,
#  'Loss/localization_loss': 0.027945602,
#  'Loss/regularization_loss': 0.058973476,
#  'Loss/total_loss': 0.17920342,
#  'learning_rate': 0.078944765}
# I1011 12:30:47.605052 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.09228434,
#  'Loss/localization_loss': 0.027945602,
#  'Loss/regularization_loss': 0.058973476,
#  'Loss/total_loss': 0.17920342,
#  'learning_rate': 0.078944765}
# INFO:tensorflow:Step 24400 per-step time 0.541s
# I1011 12:31:41.753976 139567239794688 model_lib_v2.py:705] Step 24400 per-step time 0.541s
# INFO:tensorflow:{'Loss/classification_loss': 0.16619132,
#  'Loss/localization_loss': 0.07863679,
#  'Loss/regularization_loss': 0.05899205,
#  'Loss/total_loss': 0.30382016,
#  'learning_rate': 0.0789351}
# I1011 12:31:41.754363 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.16619132,
#  'Loss/localization_loss': 0.07863679,
#  'Loss/regularization_loss': 0.05899205,
#  'Loss/total_loss': 0.30382016,
#  'learning_rate': 0.0789351}
# INFO:tensorflow:Step 24500 per-step time 0.547s
# I1011 12:32:36.418264 139567239794688 model_lib_v2.py:705] Step 24500 per-step time 0.547s
# INFO:tensorflow:{'Loss/classification_loss': 0.09496328,
#  'Loss/localization_loss': 0.04290887,
#  'Loss/regularization_loss': 0.05901954,
#  'Loss/total_loss': 0.1968917,
#  'learning_rate': 0.0789254}
# I1011 12:32:36.418653 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.09496328,
#  'Loss/localization_loss': 0.04290887,
#  'Loss/regularization_loss': 0.05901954,
#  'Loss/total_loss': 0.1968917,
#  'learning_rate': 0.0789254}
# INFO:tensorflow:Step 24600 per-step time 0.545s
# I1011 12:33:30.899336 139567239794688 model_lib_v2.py:705] Step 24600 per-step time 0.545s
# INFO:tensorflow:{'Loss/classification_loss': 0.118342616,
#  'Loss/localization_loss': 0.029220738,
#  'Loss/regularization_loss': 0.059004456,
#  'Loss/total_loss': 0.2065678,
#  'learning_rate': 0.07891565}
# I1011 12:33:30.899825 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.118342616,
#  'Loss/localization_loss': 0.029220738,
#  'Loss/regularization_loss': 0.059004456,
#  'Loss/total_loss': 0.2065678,
#  'learning_rate': 0.07891565}
# INFO:tensorflow:Step 24700 per-step time 0.541s
# I1011 12:34:24.956966 139567239794688 model_lib_v2.py:705] Step 24700 per-step time 0.541s
# INFO:tensorflow:{'Loss/classification_loss': 0.17876253,
#  'Loss/localization_loss': 0.06919152,
#  'Loss/regularization_loss': 0.05903021,
#  'Loss/total_loss': 0.30698425,
#  'learning_rate': 0.078905866}
# I1011 12:34:24.957268 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.17876253,
#  'Loss/localization_loss': 0.06919152,
#  'Loss/regularization_loss': 0.05903021,
#  'Loss/total_loss': 0.30698425,
#  'learning_rate': 0.078905866}
# INFO:tensorflow:Step 24800 per-step time 0.541s
# I1011 12:35:19.106305 139567239794688 model_lib_v2.py:705] Step 24800 per-step time 0.541s
# INFO:tensorflow:{'Loss/classification_loss': 0.14867471,
#  'Loss/localization_loss': 0.062461764,
#  'Loss/regularization_loss': 0.0590352,
#  'Loss/total_loss': 0.27017167,
#  'learning_rate': 0.07889602}
# I1011 12:35:19.106673 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.14867471,
#  'Loss/localization_loss': 0.062461764,
#  'Loss/regularization_loss': 0.0590352,
#  'Loss/total_loss': 0.27017167,
#  'learning_rate': 0.07889602}
# INFO:tensorflow:Step 24900 per-step time 0.547s
# I1011 12:36:13.796761 139567239794688 model_lib_v2.py:705] Step 24900 per-step time 0.547s
# INFO:tensorflow:{'Loss/classification_loss': 0.11719737,
#  'Loss/localization_loss': 0.042195003,
#  'Loss/regularization_loss': 0.059172142,
#  'Loss/total_loss': 0.21856453,
#  'learning_rate': 0.07888615}
# I1011 12:36:13.797132 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.11719737,
#  'Loss/localization_loss': 0.042195003,
#  'Loss/regularization_loss': 0.059172142,
#  'Loss/total_loss': 0.21856453,
#  'learning_rate': 0.07888615}
# INFO:tensorflow:Step 25000 per-step time 0.539s
# I1011 12:37:07.724275 139567239794688 model_lib_v2.py:705] Step 25000 per-step time 0.539s
# INFO:tensorflow:{'Loss/classification_loss': 0.1221119,
#  'Loss/localization_loss': 0.064526334,
#  'Loss/regularization_loss': 0.059215188,
#  'Loss/total_loss': 0.24585342,
#  'learning_rate': 0.07887623}
# I1011 12:37:07.724729 139567239794688 model_lib_v2.py:708] {'Loss/classification_loss': 0.1221119,
#  'Loss/localization_loss': 0.064526334,
#  'Loss/regularization_loss': 0.059215188,
#  'Loss/total_loss': 0.24585342,
#  'learning_rate': 0.07887623}

# %%
import os
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Create a folder in the root directory
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp -av /content/training /content/drive/MyDrive/Project-1/TrainingCheckpoints
# Out:
# '/content/training' -> '/content/drive/MyDrive/Project-1/TrainingCheckpoints/training'
# '/content/training/train' -> '/content/drive/MyDrive/Project-1/TrainingCheckpoints/training/train'
# '/content/training/train/events.out.tfevents.1697011410.f09d0ea2f4eb.4363.0.v2' -> '/content/drive/MyDrive/Project-1/TrainingCheckpoints/training/train/events.out.tfevents.1697011410.f09d0ea2f4eb.4363.0.v2'
# '/content/training/train/events.out.tfevents.1697012426.f09d0ea2f4eb.8882.0.v2' -> '/content/drive/MyDrive/Project-1/TrainingCheckpoints/training/train/events.out.tfevents.1697012426.f09d0ea2f4eb.8882.0.v2'
# '/content/training/train/events.out.tfevents.1697017591.f09d0ea2f4eb.30630.0.v2' -> '/content/drive/MyDrive/Project-1/TrainingCheckpoints/training/train/events.out.tfevents.1697017591.f09d0ea2f4eb.30630.0.v2'
# '/content/training/train/events.out.tfevents.1697021166.f09d0ea2f4eb.45556.0.v2' -> '/content/drive/MyDrive/Project-1/TrainingCheckpoints/training/train/events.out.tfevents.1697021166.f09d0ea2f4eb.45556.0.v2'
# '/content/training/.ipynb_checkpoints' -> '/content/drive/MyDrive/Project-1/TrainingCheckpoints/training/.ipynb_checkpoints'
# '/content/training/checkpoint' -> '/content/drive/MyDrive/Project-1/TrainingCheckpoints/training/checkpoint'
# '/content/training/ckpt-25.index' -> '/content/drive/MyDrive/Project-1/TrainingCheckpoints/training/ckpt-25.index'
# '/content/training/ckpt-26.index' -> '/content/drive/MyDrive/Project-1/TrainingCheckpoints/training/ckpt-26.index'
# '/content/training/ckpt-21.index' -> '/content/drive/MyDrive/Project-1/TrainingCheckpoints/training/ckpt-21.index'
# '/content/training/ckpt-22.index' -> '/content/drive/MyDrive/Project-1/TrainingCheckpoints/training/ckpt-22.index'
# '/content/training/ckpt-24.index' -> '/content/drive/MyDrive/Project-1/TrainingCheckpoints/training/ckpt-24.index'
# '/content/training/ckpt-23.index' -> '/content/drive/MyDrive/Project-1/TrainingCheckpoints/training/ckpt-23.index'
# '/content/training/ckpt-27.index' -> '/content/drive/MyDrive/Project-1/TrainingCheckpoints/training/ckpt-27.index'
# '/content/training/ckpt-21.data-00000-of-00001' -> '/content/drive/MyDrive/Project-1/TrainingCheckpoints/training/ckpt-21.data-00000-of-00001'
# '/content/training/ckpt-22.data-00000-of-00001' -> '/content/drive/MyDrive/Project-1/TrainingCheckpoints/training/ckpt-22.data-00000-of-00001'
# '/content/training/ckpt-26.data-00000-of-00001' -> '/content/drive/MyDrive/Project-1/TrainingCheckpoints/training/ckpt-26.data-00000-of-00001'
# '/content/training/ckpt-24.data-00000-of-00001' -> '/content/drive/MyDrive/Project-1/TrainingCheckpoints/training/ckpt-24.data-00000-of-00001'
# '/content/training/ckpt-25.data-00000-of-00001' -> '/content/drive/MyDrive/Project-1/TrainingCheckpoints/training/ckpt-25.data-00000-of-00001'
# '/content/training/ckpt-23.data-00000-of-00001' -> '/content/drive/MyDrive/Project-1/TrainingCheckpoints/training/ckpt-23.data-00000-of-00001'
# '/content/training/ckpt-27.data-00000-of-00001' -> '/content/drive/MyDrive/Project-1/TrainingCheckpoints/training/ckpt-27.data-00000-of-00001'

# %%
# %ls '/content/drive/MyDrive/Project-1/EfficientDet Model/training'
# Out:
# checkpoint  ckpt-15.data-00000-of-00001  ckpt-15.index

# %% [markdown]
# # New Section

# %%
#run conversion script
import re
import numpy as np

output_directory = '/content/fine_tuned_model'

#place the model weights you would like to export here
last_model_path = '/content/training'
print(last_model_path)
# !python /content/models/research/object_detection/exporter_main_v2.py \
    --trained_checkpoint_dir {last_model_path} \
    --output_directory {output_directory} \
    --pipeline_config_path {pipeline_file}
# Out:
# /content/training
# 2023-10-11 12:50:07.772159: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-10-11 12:50:12.807563: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I1011 12:50:12.842325 138065482469376 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b0
# I1011 12:50:12.842563 138065482469376 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 64
# I1011 12:50:12.842660 138065482469376 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 3
# I1011 12:50:12.849415 138065482469376 efficientnet_model.py:143] round_filter input=32 output=32
# I1011 12:50:13.110966 138065482469376 efficientnet_model.py:143] round_filter input=32 output=32
# I1011 12:50:13.111158 138065482469376 efficientnet_model.py:143] round_filter input=16 output=16
# I1011 12:50:13.231601 138065482469376 efficientnet_model.py:143] round_filter input=16 output=16
# I1011 12:50:13.231760 138065482469376 efficientnet_model.py:143] round_filter input=24 output=24
# I1011 12:50:13.542307 138065482469376 efficientnet_model.py:143] round_filter input=24 output=24
# I1011 12:50:13.542494 138065482469376 efficientnet_model.py:143] round_filter input=40 output=40
# I1011 12:50:13.833071 138065482469376 efficientnet_model.py:143] round_filter input=40 output=40
# I1011 12:50:13.833250 138065482469376 efficientnet_model.py:143] round_filter input=80 output=80
# I1011 12:50:14.265823 138065482469376 efficientnet_model.py:143] round_filter input=80 output=80
# I1011 12:50:14.266000 138065482469376 efficientnet_model.py:143] round_filter input=112 output=112
# I1011 12:50:14.705189 138065482469376 efficientnet_model.py:143] round_filter input=112 output=112
# I1011 12:50:14.705394 138065482469376 efficientnet_model.py:143] round_filter input=192 output=192
# I1011 12:50:15.266470 138065482469376 efficientnet_model.py:143] round_filter input=192 output=192
# I1011 12:50:15.266663 138065482469376 efficientnet_model.py:143] round_filter input=320 output=320
# I1011 12:50:15.403003 138065482469376 efficientnet_model.py:143] round_filter input=1280 output=1280
# I1011 12:50:15.473515 138065482469376 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W1011 12:50:17.732565 138065482469376 deprecation.py:641] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# I1011 12:50:21.964754 138065482469376 api.py:459] feature_map_spatial_dims: [(64, 64), (32, 32), (16, 16), (8, 8), (4, 4)]
# I1011 12:50:35.803494 138065482469376 api.py:459] feature_map_spatial_dims: [(64, 64), (32, 32), (16, 16), (8, 8), (4, 4)]
# I1011 12:50:42.895043 138065482469376 api.py:459] feature_map_spatial_dims: [(64, 64), (32, 32), (16, 16), (8, 8), (4, 4)]
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7d915c25da80>, because it is not built.
# W1011 12:50:45.329991 138065482469376 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7d915c25da80>, because it is not built.
# W1011 12:51:36.263742 138065482469376 save.py:274] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 437). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/fine_tuned_model/saved_model/assets
# I1011 12:52:10.026492 138065482469376 builder_impl.py:797] Assets written to: /content/fine_tuned_model/saved_model/assets
# INFO:tensorflow:Writing pipeline config file to /content/fine_tuned_model/pipeline.config
# I1011 12:52:13.300864 138065482469376 config_util.py:253] Writing pipeline config file to /content/fine_tuned_model/pipeline.config

# %%
# !cp -av /content/fine_tuned_model /content/drive/MyDrive/Project-1/fine_tuned_model_v2
# Out:
# '/content/fine_tuned_model' -> '/content/drive/MyDrive/Project-1/fine_tuned_model_v2/fine_tuned_model'
# '/content/fine_tuned_model/checkpoint' -> '/content/drive/MyDrive/Project-1/fine_tuned_model_v2/fine_tuned_model/checkpoint'
# '/content/fine_tuned_model/checkpoint/ckpt-0.data-00000-of-00001' -> '/content/drive/MyDrive/Project-1/fine_tuned_model_v2/fine_tuned_model/checkpoint/ckpt-0.data-00000-of-00001'
# '/content/fine_tuned_model/checkpoint/checkpoint' -> '/content/drive/MyDrive/Project-1/fine_tuned_model_v2/fine_tuned_model/checkpoint/checkpoint'
# '/content/fine_tuned_model/checkpoint/ckpt-0.index' -> '/content/drive/MyDrive/Project-1/fine_tuned_model_v2/fine_tuned_model/checkpoint/ckpt-0.index'
# '/content/fine_tuned_model/saved_model' -> '/content/drive/MyDrive/Project-1/fine_tuned_model_v2/fine_tuned_model/saved_model'
# '/content/fine_tuned_model/saved_model/variables' -> '/content/drive/MyDrive/Project-1/fine_tuned_model_v2/fine_tuned_model/saved_model/variables'
# '/content/fine_tuned_model/saved_model/variables/variables.data-00000-of-00001' -> '/content/drive/MyDrive/Project-1/fine_tuned_model_v2/fine_tuned_model/saved_model/variables/variables.data-00000-of-00001'
# '/content/fine_tuned_model/saved_model/variables/variables.index' -> '/content/drive/MyDrive/Project-1/fine_tuned_model_v2/fine_tuned_model/saved_model/variables/variables.index'
# '/content/fine_tuned_model/saved_model/assets' -> '/content/drive/MyDrive/Project-1/fine_tuned_model_v2/fine_tuned_model/saved_model/assets'
# '/content/fine_tuned_model/saved_model/fingerprint.pb' -> '/content/drive/MyDrive/Project-1/fine_tuned_model_v2/fine_tuned_model/saved_model/fingerprint.pb'
# '/content/fine_tuned_model/saved_model/saved_model.pb' -> '/content/drive/MyDrive/Project-1/fine_tuned_model_v2/fine_tuned_model/saved_model/saved_model.pb'
# '/content/fine_tuned_model/pipeline.config' -> '/content/drive/MyDrive/Project-1/fine_tuned_model_v2/fine_tuned_model/pipeline.config'

# %%
# %load_ext tensorboard
# %tensorboard --logdir '/content/training/train'
